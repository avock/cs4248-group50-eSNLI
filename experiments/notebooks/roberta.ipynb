# %%
import pandas as pd
import time, datetime, numpy as np
import random

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# from transformers import BertTokenizer, BertForSequenceClassification
from transformers import RobertaForSequenceClassification, RobertaTokenizer
from transformers import AdamW, get_linear_schedule_with_warmup
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AdamW, get_linear_schedule_with_warmup

# %% [markdown]
# ## Mounting Google Drive to Collab

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/CS4248/esnli_train.csv')
test = pd.read_csv('/content/drive/MyDrive/CS4248/esnli_test.csv')
# Out:
# Mounted at /content/drive

# %%
df.shape
# Out:
# (259999, 10)

# %%
df.head()
# Out:
#                 pairID     gold_label  \
# 0  3416050480.jpg#4r1n        neutral
# 1  3416050480.jpg#4r1c  contradiction
# 2  3416050480.jpg#4r1e     entailment
# 3  2267923837.jpg#2r1n        neutral
# 4  2267923837.jpg#2r1e     entailment
#
#                                            Sentence1  \
# 0  A person on a horse jumps over a broken down a...
# 1  A person on a horse jumps over a broken down a...
# 2  A person on a horse jumps over a broken down a...
# 3              Children smiling and waving at camera
# 4              Children smiling and waving at camera
#
#                                            Sentence2  \
# 0  A person is training his horse for a competition.
# 1      A person is at a diner, ordering an omelette.
# 2                  A person is outdoors, on a horse.
# 3                  They are smiling at their parents
# 4                         There are children present
#
#                                        Explanation_1        WorkerId  \
# 0   the person is not necessarily training his horse   AF0PI3RISB5Q7
# 1  One cannot be on a jumping horse cannot be a d...  A36ZT2WFIA2HMF
# 2                 a broken down airplane is outdoors  A2GK75ZQTX2RDZ
# 3  Just because they are smiling and waving at a ...  A18TOIDG32QICP
# 4  The children must be present to see them smili...   AEX0YE6TUZRHT
#
#                                   Sentence1_marked_1  \
# 0  A person on a horse jumps over a broken down a...
# 1   A person *on* *a* *horse* *jumps* over a brok...
# 2   A person on a horse jumps over *a* *broken* *...
# 3              Children smiling and waving at camera
# 4      *Children* *smiling* *and* *waving* at camera
#
#                                   Sentence2_marked_1 Sentence1_Highlighted_1  \
# 0   A person is *training* *his* *horse* for a co...                      {}
# 1   A person *is* *at* *a* *diner,* *ordering* an...                 4,2,3,5
# 2                A person is *outdoors,* on a horse.                8,9,10,7
# 3            They are smiling *at* *their* *parents*                      {}
# 4                       There are children *present*                 0,1,3,2
#
#   Sentence2_Highlighted_1
# 0                   3,4,5
# 1               2,5,4,3,6
# 2                       3
# 3                   5,3,4
# 4                       3

# %% [markdown]
# ## Utility Functions

# %%
def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    elapsed_rounded = int(round((elapsed)))
    return str(datetime.timedelta(seconds=elapsed_rounded))

def select_cols(df, col_list):
    '''
    Select columns from a dataframe
    '''
    return df[col_list]

# %% [markdown]
# ## Data Pre-processing Utility Functions

# %%
def combine_sentences(df, col_list):

    # start_token = '[CLS]'
    # seperator = '[SEP]'

    # combined_text_list = [f'{start_token}{s1}{seperator}{s2}' for s1, s2 in zip(sentence1, sentence2)]
    # return combined_text_list

    results_df = df.copy()

    results_df['combined_text'] = '[CLS]' + results_df[col_list].astype(str).agg('[SEP]'.join, axis=1)

    return results_df

def permute_words(explanation):
    words = explanation.split()
    random.shuffle(words)
    return ' '.join(words)

# %% [markdown]
# Train/Test Input Data Handling

# %%
# target_cols = ['Sentence1', 'Sentence2', 'gold_label'] # Premise, Hypothesis
# target_cols = ['Sentence1', 'Sentence2', 'Explanation_1', 'gold_label'] # Premise, Hypothesis, Explanation
# target_cols = ['Sentence2', 'Sentence1', 'gold_label'] # Hypothesis, Premise
target_cols = ['Sentence1', 'Explanation_1', 'Sentence2', 'gold_label'] # Premise, Explanation, Hypothesis

df = select_cols(df, target_cols)
test_df = select_cols(test, target_cols)

df.head()
# Out:
#                                            Sentence1  \
# 0  A person on a horse jumps over a broken down a...
# 1  A person on a horse jumps over a broken down a...
# 2  A person on a horse jumps over a broken down a...
# 3              Children smiling and waving at camera
# 4              Children smiling and waving at camera
#
#                                        Explanation_1  \
# 0   the person is not necessarily training his horse
# 1  One cannot be on a jumping horse cannot be a d...
# 2                 a broken down airplane is outdoors
# 3  Just because they are smiling and waving at a ...
# 4  The children must be present to see them smili...
#
#                                            Sentence2     gold_label
# 0  A person is training his horse for a competition.        neutral
# 1      A person is at a diner, ordering an omelette.  contradiction
# 2                  A person is outdoors, on a horse.     entailment
# 3                  They are smiling at their parents        neutral
# 4                         There are children present     entailment

# %%
df['Explanation_1'] = df['Explanation_1'].astype(str).apply(permute_words)
test_df['Explanation_1'] = test_df['Explanation_1'].astype(str).apply(permute_words)


df.head()
# Out:
# <ipython-input-9-30ef9b3dcd30>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Explanation_1'] = test_df['Explanation_1'].astype(str).apply(permute_words)
#                                            Sentence1  \
# 0  A person on a horse jumps over a broken down a...
# 1  A person on a horse jumps over a broken down a...
# 2  A person on a horse jumps over a broken down a...
# 3              Children smiling and waving at camera
# 4              Children smiling and waving at camera
#
#                                        Explanation_1  \
# 0   not is horse the training necessarily his person
# 1  cannot be jumping diner ordering a food. One b...
# 2                 a down outdoors is airplane broken
# 3  or and does anyone at anyone it not smiling a ...
# 4  waving. The them smiling children and to be se...
#
#                                            Sentence2     gold_label
# 0  A person is training his horse for a competition.        neutral
# 1      A person is at a diner, ordering an omelette.  contradiction
# 2                  A person is outdoors, on a horse.     entailment
# 3                  They are smiling at their parents        neutral
# 4                         There are children present     entailment

# %%
df = combine_sentences(df, target_cols[:-1])
test_df = combine_sentences(test_df, target_cols[:-1])

df.head()

lables = {
    'entailment': 0,
    'neutral': 1,
    'contradiction': 2
}

df['labels'] = df['gold_label'].map(lables)
test_df['labels'] = test_df['gold_label'].map(lables)

# %%
df.head()
# Out:
#                                            Sentence1  \
# 0  A person on a horse jumps over a broken down a...
# 1  A person on a horse jumps over a broken down a...
# 2  A person on a horse jumps over a broken down a...
# 3              Children smiling and waving at camera
# 4              Children smiling and waving at camera
#
#                                        Explanation_1  \
# 0   not is horse the training necessarily his person
# 1  cannot be jumping diner ordering a food. One b...
# 2                 a down outdoors is airplane broken
# 3  or and does anyone at anyone it not smiling a ...
# 4  waving. The them smiling children and to be se...
#
#                                            Sentence2     gold_label  \
# 0  A person is training his horse for a competition.        neutral
# 1      A person is at a diner, ordering an omelette.  contradiction
# 2                  A person is outdoors, on a horse.     entailment
# 3                  They are smiling at their parents        neutral
# 4                         There are children present     entailment
#
#                                        combined_text  labels
# 0  [CLS]A person on a horse jumps over a broken d...       1
# 1  [CLS]A person on a horse jumps over a broken d...       2
# 2  [CLS]A person on a horse jumps over a broken d...       0
# 3  [CLS]Children smiling and waving at camera[SEP...       1
# 4  [CLS]Children smiling and waving at camera[SEP...       0

# %%
df['combined_text'][0]
# Out:
# '[CLS]A person on a horse jumps over a broken down airplane.[SEP]not is horse the training necessarily his person[SEP]A person is training his horse for a competition.'

# %%
X = df['combined_text']
y = df['labels']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((233999,), (26000,), (233999,), (26000,))

# %%
X_test = test_df['combined_text']
y_test = test_df['labels']

X_test.shape, y_test.shape
# Out:
# ((9824,), (9824,))

# %%
class NliDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

# tokenize train/validation data
train_encodings = tokenizer(X_train.tolist(), truncation=True, padding=True)
val_encodings = tokenizer(X_val.tolist(), truncation=True, padding=True)

# tokenize test data
test_encodings = tokenizer(X_test.tolist(), truncation=True, padding=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]

# %%
# creating Dataset objects
train_dataset = NliDataset(train_encodings, y_train.tolist())
val_dataset = NliDataset(val_encodings, y_val.tolist())
test_dataset = NliDataset(test_encodings, y_test.tolist())

# Create DataLoader instances
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
validation_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
model = RobertaForSequenceClassification.from_pretrained(
    "roberta-base",
    num_labels = 3,
    output_attentions = False,
    output_hidden_states = False,
)

#unfreezing layer 11 and the classifier. note: the pooler is still frozen
for name, param in model.named_parameters():
    if 'classifier' not in name and '11' not in name:
        param.requires_grad = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=3, bias=True)
#   )
# )

# %%
if torch.cuda.is_available():
    print("CUDA is available. Using GPU:", torch.cuda.get_device_name(0))
else:
    print("CUDA is not available. Using CPU.")

print("Current device model is on:", model.device)
# Out:
# CUDA is available. Using GPU: Tesla V100-SXM2-16GB
# Current device model is on: cuda:0

# %%
optimizer = AdamW(model.parameters(),
                  lr = 5e-5,
                  eps = 1e-8
                 )

epochs = 2
total_steps = len(train_loader) * epochs

scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0,
                                            num_training_steps = total_steps)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:429: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Begin Training Loop
loss_values = []

for epoch_i in range(0, epochs):
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # time taken for each epoch
    t0 = time.time()

    total_loss = 0

    model.train()

    for step, batch in enumerate(train_loader):
        if step % 40 == 0 and not step == 0:
            elapsed = format_time(time.time() - t0)
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_loader), elapsed))

        # Unpack this training batch from our dataloader.
        #
        # As we unpack the batch, we'll also copy each tensor to the GPU using the
        # `to` method.
        #
        # `batch` contains three pytorch tensors:
        #   [0]: input ids
        #   [1]: attention masks
        #   [2]: labels
        b_input_ids = batch['input_ids'].to(device)
        b_input_mask = batch['attention_mask'].to(device)
        b_labels = batch['labels'].to(device)

        # clear previously calculated gradient before backward pass
        model.zero_grad()

        # forward pass
        outputs = model(b_input_ids,
                        token_type_ids=None,
                        attention_mask=b_input_mask,
                        labels=b_labels)

        loss = outputs.loss

        # Accumulate the training loss over all of the batches so that we can
        # calculate the average loss at the end. `loss` is a Tensor containing a
        # single value; the `.item()` function just returns the Python value
        # from the tensor.
        total_loss += loss.item()

        # backwar pass
        loss.backward()

        # Clip the norm of the gradients to 1.0, helps prevents "exploding gradient"
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update parameters and take a step
        optimizer.step()

        # Update the learning rate.
        scheduler.step()

    avg_train_loss = total_loss / len(train_loader)
    loss_values.append(avg_train_loss)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epoch took: {:}".format(format_time(time.time() - t0)))

print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 2 ========
# Training...
#   Batch    40  of  14,625.    Elapsed: 0:00:04.
#   Batch    80  of  14,625.    Elapsed: 0:00:06.
#   Batch   120  of  14,625.    Elapsed: 0:00:09.
#   Batch   160  of  14,625.    Elapsed: 0:00:12.
#   Batch   200  of  14,625.    Elapsed: 0:00:14.
#   Batch   240  of  14,625.    Elapsed: 0:00:17.
#   Batch   280  of  14,625.    Elapsed: 0:00:19.
#   Batch   320  of  14,625.    Elapsed: 0:00:22.
#   Batch   360  of  14,625.    Elapsed: 0:00:25.
#   Batch   400  of  14,625.    Elapsed: 0:00:27.
#   Batch   440  of  14,625.    Elapsed: 0:00:30.
#   Batch   480  of  14,625.    Elapsed: 0:00:32.
#   Batch   520  of  14,625.    Elapsed: 0:00:35.
#   Batch   560  of  14,625.    Elapsed: 0:00:38.
#   Batch   600  of  14,625.    Elapsed: 0:00:40.
#   Batch   640  of  14,625.    Elapsed: 0:00:43.
#   Batch   680  of  14,625.    Elapsed: 0:00:45.
#   Batch   720  of  14,625.    Elapsed: 0:00:48.
#   Batch   760  of  14,625.    Elapsed: 0:00:51.
#   Batch   800  of  14,625.    Elapsed: 0:00:53.
#   Batch   840  of  14,625.    Elapsed: 0:00:56.
#   Batch   880  of  14,625.    Elapsed: 0:00:58.
#   Batch   920  of  14,625.    Elapsed: 0:01:01.
#   Batch   960  of  14,625.    Elapsed: 0:01:04.
#   Batch 1,000  of  14,625.    Elapsed: 0:01:06.
#   Batch 1,040  of  14,625.    Elapsed: 0:01:09.
#   Batch 1,080  of  14,625.    Elapsed: 0:01:11.
#   Batch 1,120  of  14,625.    Elapsed: 0:01:14.
#   Batch 1,160  of  14,625.    Elapsed: 0:01:17.
#   Batch 1,200  of  14,625.    Elapsed: 0:01:19.
#   Batch 1,240  of  14,625.    Elapsed: 0:01:22.
#   Batch 1,280  of  14,625.    Elapsed: 0:01:24.
#   Batch 1,320  of  14,625.    Elapsed: 0:01:27.
#   Batch 1,360  of  14,625.    Elapsed: 0:01:30.
#   Batch 1,400  of  14,625.    Elapsed: 0:01:32.
#   Batch 1,440  of  14,625.    Elapsed: 0:01:35.
#   Batch 1,480  of  14,625.    Elapsed: 0:01:37.
#   Batch 1,520  of  14,625.    Elapsed: 0:01:40.
#   Batch 1,560  of  14,625.    Elapsed: 0:01:43.
#   Batch 1,600  of  14,625.    Elapsed: 0:01:45.
#   Batch 1,640  of  14,625.    Elapsed: 0:01:48.
#   Batch 1,680  of  14,625.    Elapsed: 0:01:50.
#   Batch 1,720  of  14,625.    Elapsed: 0:01:53.
#   Batch 1,760  of  14,625.    Elapsed: 0:01:56.
#   Batch 1,800  of  14,625.    Elapsed: 0:01:58.
#   Batch 1,840  of  14,625.    Elapsed: 0:02:01.
#   Batch 1,880  of  14,625.    Elapsed: 0:02:03.
#   Batch 1,920  of  14,625.    Elapsed: 0:02:06.
#   Batch 1,960  of  14,625.    Elapsed: 0:02:09.
#   Batch 2,000  of  14,625.    Elapsed: 0:02:11.
#   Batch 2,040  of  14,625.    Elapsed: 0:02:14.
#   Batch 2,080  of  14,625.    Elapsed: 0:02:16.
#   Batch 2,120  of  14,625.    Elapsed: 0:02:19.
#   Batch 2,160  of  14,625.    Elapsed: 0:02:22.
#   Batch 2,200  of  14,625.    Elapsed: 0:02:24.
#   Batch 2,240  of  14,625.    Elapsed: 0:02:27.
#   Batch 2,280  of  14,625.    Elapsed: 0:02:30.
#   Batch 2,320  of  14,625.    Elapsed: 0:02:32.
#   Batch 2,360  of  14,625.    Elapsed: 0:02:35.
#   Batch 2,400  of  14,625.    Elapsed: 0:02:37.
#   Batch 2,440  of  14,625.    Elapsed: 0:02:40.
#   Batch 2,480  of  14,625.    Elapsed: 0:02:43.
#   Batch 2,520  of  14,625.    Elapsed: 0:02:45.
#   Batch 2,560  of  14,625.    Elapsed: 0:02:48.
#   Batch 2,600  of  14,625.    Elapsed: 0:02:50.
#   Batch 2,640  of  14,625.    Elapsed: 0:02:53.
#   Batch 2,680  of  14,625.    Elapsed: 0:02:56.
#   Batch 2,720  of  14,625.    Elapsed: 0:02:58.
#   Batch 2,760  of  14,625.    Elapsed: 0:03:01.
#   Batch 2,800  of  14,625.    Elapsed: 0:03:03.
#   Batch 2,840  of  14,625.    Elapsed: 0:03:06.
#   Batch 2,880  of  14,625.    Elapsed: 0:03:09.
#   Batch 2,920  of  14,625.    Elapsed: 0:03:11.
#   Batch 2,960  of  14,625.    Elapsed: 0:03:14.
#   Batch 3,000  of  14,625.    Elapsed: 0:03:16.
#   Batch 3,040  of  14,625.    Elapsed: 0:03:19.
#   Batch 3,080  of  14,625.    Elapsed: 0:03:22.
#   Batch 3,120  of  14,625.    Elapsed: 0:03:24.
#   Batch 3,160  of  14,625.    Elapsed: 0:03:27.
#   Batch 3,200  of  14,625.    Elapsed: 0:03:29.
#   Batch 3,240  of  14,625.    Elapsed: 0:03:32.
#   Batch 3,280  of  14,625.    Elapsed: 0:03:35.
#   Batch 3,320  of  14,625.    Elapsed: 0:03:37.
#   Batch 3,360  of  14,625.    Elapsed: 0:03:40.
#   Batch 3,400  of  14,625.    Elapsed: 0:03:42.
#   Batch 3,440  of  14,625.    Elapsed: 0:03:45.
#   Batch 3,480  of  14,625.    Elapsed: 0:03:48.
#   Batch 3,520  of  14,625.    Elapsed: 0:03:50.
#   Batch 3,560  of  14,625.    Elapsed: 0:03:53.
#   Batch 3,600  of  14,625.    Elapsed: 0:03:56.
#   Batch 3,640  of  14,625.    Elapsed: 0:03:58.
#   Batch 3,680  of  14,625.    Elapsed: 0:04:01.
#   Batch 3,720  of  14,625.    Elapsed: 0:04:03.
#   Batch 3,760  of  14,625.    Elapsed: 0:04:06.
#   Batch 3,800  of  14,625.    Elapsed: 0:04:09.
#   Batch 3,840  of  14,625.    Elapsed: 0:04:11.
#   Batch 3,880  of  14,625.    Elapsed: 0:04:14.
#   Batch 3,920  of  14,625.    Elapsed: 0:04:16.
#   Batch 3,960  of  14,625.    Elapsed: 0:04:19.
#   Batch 4,000  of  14,625.    Elapsed: 0:04:22.
#   Batch 4,040  of  14,625.    Elapsed: 0:04:24.
#   Batch 4,080  of  14,625.    Elapsed: 0:04:27.
#   Batch 4,120  of  14,625.    Elapsed: 0:04:29.
#   Batch 4,160  of  14,625.    Elapsed: 0:04:32.
#   Batch 4,200  of  14,625.    Elapsed: 0:04:35.
#   Batch 4,240  of  14,625.    Elapsed: 0:04:37.
#   Batch 4,280  of  14,625.    Elapsed: 0:04:40.
#   Batch 4,320  of  14,625.    Elapsed: 0:04:43.
#   Batch 4,360  of  14,625.    Elapsed: 0:04:45.
#   Batch 4,400  of  14,625.    Elapsed: 0:04:48.
#   Batch 4,440  of  14,625.    Elapsed: 0:04:50.
#   Batch 4,480  of  14,625.    Elapsed: 0:04:53.
#   Batch 4,520  of  14,625.    Elapsed: 0:04:56.
#   Batch 4,560  of  14,625.    Elapsed: 0:04:58.
#   Batch 4,600  of  14,625.    Elapsed: 0:05:01.
#   Batch 4,640  of  14,625.    Elapsed: 0:05:03.
#   Batch 4,680  of  14,625.    Elapsed: 0:05:06.
#   Batch 4,720  of  14,625.    Elapsed: 0:05:09.
#   Batch 4,760  of  14,625.    Elapsed: 0:05:11.
#   Batch 4,800  of  14,625.    Elapsed: 0:05:14.
#   Batch 4,840  of  14,625.    Elapsed: 0:05:16.
#   Batch 4,880  of  14,625.    Elapsed: 0:05:19.
#   Batch 4,920  of  14,625.    Elapsed: 0:05:22.
#   Batch 4,960  of  14,625.    Elapsed: 0:05:24.
#   Batch 5,000  of  14,625.    Elapsed: 0:05:27.
#   Batch 5,040  of  14,625.    Elapsed: 0:05:29.
#   Batch 5,080  of  14,625.    Elapsed: 0:05:32.
#   Batch 5,120  of  14,625.    Elapsed: 0:05:35.
#   Batch 5,160  of  14,625.    Elapsed: 0:05:37.
#   Batch 5,200  of  14,625.    Elapsed: 0:05:40.
#   Batch 5,240  of  14,625.    Elapsed: 0:05:42.
#   Batch 5,280  of  14,625.    Elapsed: 0:05:45.
#   Batch 5,320  of  14,625.    Elapsed: 0:05:48.
#   Batch 5,360  of  14,625.    Elapsed: 0:05:50.
#   Batch 5,400  of  14,625.    Elapsed: 0:05:53.
#   Batch 5,440  of  14,625.    Elapsed: 0:05:55.
#   Batch 5,480  of  14,625.    Elapsed: 0:05:58.
#   Batch 5,520  of  14,625.    Elapsed: 0:06:01.
#   Batch 5,560  of  14,625.    Elapsed: 0:06:03.
#   Batch 5,600  of  14,625.    Elapsed: 0:06:06.
#   Batch 5,640  of  14,625.    Elapsed: 0:06:09.
#   Batch 5,680  of  14,625.    Elapsed: 0:06:11.
#   Batch 5,720  of  14,625.    Elapsed: 0:06:14.
#   Batch 5,760  of  14,625.    Elapsed: 0:06:16.
#   Batch 5,800  of  14,625.    Elapsed: 0:06:19.
#   Batch 5,840  of  14,625.    Elapsed: 0:06:22.
#   Batch 5,880  of  14,625.    Elapsed: 0:06:24.
#   Batch 5,920  of  14,625.    Elapsed: 0:06:27.
#   Batch 5,960  of  14,625.    Elapsed: 0:06:29.
#   Batch 6,000  of  14,625.    Elapsed: 0:06:32.
#   Batch 6,040  of  14,625.    Elapsed: 0:06:35.
#   Batch 6,080  of  14,625.    Elapsed: 0:06:37.
#   Batch 6,120  of  14,625.    Elapsed: 0:06:40.
#   Batch 6,160  of  14,625.    Elapsed: 0:06:42.
#   Batch 6,200  of  14,625.    Elapsed: 0:06:45.
#   Batch 6,240  of  14,625.    Elapsed: 0:06:48.
#   Batch 6,280  of  14,625.    Elapsed: 0:06:50.
#   Batch 6,320  of  14,625.    Elapsed: 0:06:53.
#   Batch 6,360  of  14,625.    Elapsed: 0:06:55.
#   Batch 6,400  of  14,625.    Elapsed: 0:06:58.
#   Batch 6,440  of  14,625.    Elapsed: 0:07:01.
#   Batch 6,480  of  14,625.    Elapsed: 0:07:03.
#   Batch 6,520  of  14,625.    Elapsed: 0:07:06.
#   Batch 6,560  of  14,625.    Elapsed: 0:07:08.
#   Batch 6,600  of  14,625.    Elapsed: 0:07:11.
#   Batch 6,640  of  14,625.    Elapsed: 0:07:14.
#   Batch 6,680  of  14,625.    Elapsed: 0:07:16.
#   Batch 6,720  of  14,625.    Elapsed: 0:07:19.
#   Batch 6,760  of  14,625.    Elapsed: 0:07:21.
#   Batch 6,800  of  14,625.    Elapsed: 0:07:24.
#   Batch 6,840  of  14,625.    Elapsed: 0:07:27.
#   Batch 6,880  of  14,625.    Elapsed: 0:07:29.
#   Batch 6,920  of  14,625.    Elapsed: 0:07:32.
#   Batch 6,960  of  14,625.    Elapsed: 0:07:34.
#   Batch 7,000  of  14,625.    Elapsed: 0:07:37.
#   Batch 7,040  of  14,625.    Elapsed: 0:07:40.
#   Batch 7,080  of  14,625.    Elapsed: 0:07:42.
#   Batch 7,120  of  14,625.    Elapsed: 0:07:45.
#   Batch 7,160  of  14,625.    Elapsed: 0:07:48.
#   Batch 7,200  of  14,625.    Elapsed: 0:07:50.
#   Batch 7,240  of  14,625.    Elapsed: 0:07:53.
#   Batch 7,280  of  14,625.    Elapsed: 0:07:55.
#   Batch 7,320  of  14,625.    Elapsed: 0:07:58.
#   Batch 7,360  of  14,625.    Elapsed: 0:08:01.
#   Batch 7,400  of  14,625.    Elapsed: 0:08:03.
#   Batch 7,440  of  14,625.    Elapsed: 0:08:06.
#   Batch 7,480  of  14,625.    Elapsed: 0:08:08.
#   Batch 7,520  of  14,625.    Elapsed: 0:08:11.
#   Batch 7,560  of  14,625.    Elapsed: 0:08:14.
#   Batch 7,600  of  14,625.    Elapsed: 0:08:16.
#   Batch 7,640  of  14,625.    Elapsed: 0:08:19.
#   Batch 7,680  of  14,625.    Elapsed: 0:08:21.
#   Batch 7,720  of  14,625.    Elapsed: 0:08:24.
#   Batch 7,760  of  14,625.    Elapsed: 0:08:27.
#   Batch 7,800  of  14,625.    Elapsed: 0:08:29.
#   Batch 7,840  of  14,625.    Elapsed: 0:08:32.
#   Batch 7,880  of  14,625.    Elapsed: 0:08:34.
#   Batch 7,920  of  14,625.    Elapsed: 0:08:37.
#   Batch 7,960  of  14,625.    Elapsed: 0:08:40.
#   Batch 8,000  of  14,625.    Elapsed: 0:08:42.
#   Batch 8,040  of  14,625.    Elapsed: 0:08:45.
#   Batch 8,080  of  14,625.    Elapsed: 0:08:47.
#   Batch 8,120  of  14,625.    Elapsed: 0:08:50.
#   Batch 8,160  of  14,625.    Elapsed: 0:08:53.
#   Batch 8,200  of  14,625.    Elapsed: 0:08:55.
#   Batch 8,240  of  14,625.    Elapsed: 0:08:58.
#   Batch 8,280  of  14,625.    Elapsed: 0:09:01.
#   Batch 8,320  of  14,625.    Elapsed: 0:09:03.
#   Batch 8,360  of  14,625.    Elapsed: 0:09:06.
#   Batch 8,400  of  14,625.    Elapsed: 0:09:08.
#   Batch 8,440  of  14,625.    Elapsed: 0:09:11.
#   Batch 8,480  of  14,625.    Elapsed: 0:09:14.
#   Batch 8,520  of  14,625.    Elapsed: 0:09:16.
#   Batch 8,560  of  14,625.    Elapsed: 0:09:19.
#   Batch 8,600  of  14,625.    Elapsed: 0:09:21.
#   Batch 8,640  of  14,625.    Elapsed: 0:09:24.
#   Batch 8,680  of  14,625.    Elapsed: 0:09:27.
#   Batch 8,720  of  14,625.    Elapsed: 0:09:29.
#   Batch 8,760  of  14,625.    Elapsed: 0:09:32.
#   Batch 8,800  of  14,625.    Elapsed: 0:09:34.
#   Batch 8,840  of  14,625.    Elapsed: 0:09:37.
#   Batch 8,880  of  14,625.    Elapsed: 0:09:40.
#   Batch 8,920  of  14,625.    Elapsed: 0:09:42.
#   Batch 8,960  of  14,625.    Elapsed: 0:09:45.
#   Batch 9,000  of  14,625.    Elapsed: 0:09:47.
#   Batch 9,040  of  14,625.    Elapsed: 0:09:50.
#   Batch 9,080  of  14,625.    Elapsed: 0:09:53.
#   Batch 9,120  of  14,625.    Elapsed: 0:09:55.
#   Batch 9,160  of  14,625.    Elapsed: 0:09:58.
#   Batch 9,200  of  14,625.    Elapsed: 0:10:00.
#   Batch 9,240  of  14,625.    Elapsed: 0:10:03.
#   Batch 9,280  of  14,625.    Elapsed: 0:10:06.
#   Batch 9,320  of  14,625.    Elapsed: 0:10:08.
#   Batch 9,360  of  14,625.    Elapsed: 0:10:11.
#   Batch 9,400  of  14,625.    Elapsed: 0:10:13.
#   Batch 9,440  of  14,625.    Elapsed: 0:10:16.
#   Batch 9,480  of  14,625.    Elapsed: 0:10:19.
#   Batch 9,520  of  14,625.    Elapsed: 0:10:21.
#   Batch 9,560  of  14,625.    Elapsed: 0:10:24.
#   Batch 9,600  of  14,625.    Elapsed: 0:10:27.
#   Batch 9,640  of  14,625.    Elapsed: 0:10:29.
#   Batch 9,680  of  14,625.    Elapsed: 0:10:32.
#   Batch 9,720  of  14,625.    Elapsed: 0:10:34.
#   Batch 9,760  of  14,625.    Elapsed: 0:10:37.
#   Batch 9,800  of  14,625.    Elapsed: 0:10:40.
#   Batch 9,840  of  14,625.    Elapsed: 0:10:42.
#   Batch 9,880  of  14,625.    Elapsed: 0:10:45.
#   Batch 9,920  of  14,625.    Elapsed: 0:10:47.
#   Batch 9,960  of  14,625.    Elapsed: 0:10:50.
#   Batch 10,000  of  14,625.    Elapsed: 0:10:53.
#   Batch 10,040  of  14,625.    Elapsed: 0:10:55.
#   Batch 10,080  of  14,625.    Elapsed: 0:10:58.
#   Batch 10,120  of  14,625.    Elapsed: 0:11:00.
#   Batch 10,160  of  14,625.    Elapsed: 0:11:03.
#   Batch 10,200  of  14,625.    Elapsed: 0:11:06.
#   Batch 10,240  of  14,625.    Elapsed: 0:11:08.
#   Batch 10,280  of  14,625.    Elapsed: 0:11:11.
#   Batch 10,320  of  14,625.    Elapsed: 0:11:13.
#   Batch 10,360  of  14,625.    Elapsed: 0:11:16.
#   Batch 10,400  of  14,625.    Elapsed: 0:11:19.
#   Batch 10,440  of  14,625.    Elapsed: 0:11:21.
#   Batch 10,480  of  14,625.    Elapsed: 0:11:24.
#   Batch 10,520  of  14,625.    Elapsed: 0:11:26.
#   Batch 10,560  of  14,625.    Elapsed: 0:11:29.
#   Batch 10,600  of  14,625.    Elapsed: 0:11:32.
#   Batch 10,640  of  14,625.    Elapsed: 0:11:34.
#   Batch 10,680  of  14,625.    Elapsed: 0:11:37.
#   Batch 10,720  of  14,625.    Elapsed: 0:11:39.
#   Batch 10,760  of  14,625.    Elapsed: 0:11:42.
#   Batch 10,800  of  14,625.    Elapsed: 0:11:45.
#   Batch 10,840  of  14,625.    Elapsed: 0:11:47.
#   Batch 10,880  of  14,625.    Elapsed: 0:11:50.
#   Batch 10,920  of  14,625.    Elapsed: 0:11:52.
#   Batch 10,960  of  14,625.    Elapsed: 0:11:55.
#   Batch 11,000  of  14,625.    Elapsed: 0:11:58.
#   Batch 11,040  of  14,625.    Elapsed: 0:12:00.
#   Batch 11,080  of  14,625.    Elapsed: 0:12:03.
#   Batch 11,120  of  14,625.    Elapsed: 0:12:06.
#   Batch 11,160  of  14,625.    Elapsed: 0:12:08.
#   Batch 11,200  of  14,625.    Elapsed: 0:12:11.
#   Batch 11,240  of  14,625.    Elapsed: 0:12:13.
#   Batch 11,280  of  14,625.    Elapsed: 0:12:16.
#   Batch 11,320  of  14,625.    Elapsed: 0:12:19.
#   Batch 11,360  of  14,625.    Elapsed: 0:12:21.
#   Batch 11,400  of  14,625.    Elapsed: 0:12:24.
#   Batch 11,440  of  14,625.    Elapsed: 0:12:26.
#   Batch 11,480  of  14,625.    Elapsed: 0:12:29.
#   Batch 11,520  of  14,625.    Elapsed: 0:12:32.
#   Batch 11,560  of  14,625.    Elapsed: 0:12:34.
#   Batch 11,600  of  14,625.    Elapsed: 0:12:37.
#   Batch 11,640  of  14,625.    Elapsed: 0:12:39.
#   Batch 11,680  of  14,625.    Elapsed: 0:12:42.
#   Batch 11,720  of  14,625.    Elapsed: 0:12:45.
#   Batch 11,760  of  14,625.    Elapsed: 0:12:47.
#   Batch 11,800  of  14,625.    Elapsed: 0:12:50.
#   Batch 11,840  of  14,625.    Elapsed: 0:12:52.
#   Batch 11,880  of  14,625.    Elapsed: 0:12:55.
#   Batch 11,920  of  14,625.    Elapsed: 0:12:58.
#   Batch 11,960  of  14,625.    Elapsed: 0:13:00.
#   Batch 12,000  of  14,625.    Elapsed: 0:13:03.
#   Batch 12,040  of  14,625.    Elapsed: 0:13:05.
#   Batch 12,080  of  14,625.    Elapsed: 0:13:08.
#   Batch 12,120  of  14,625.    Elapsed: 0:13:11.
#   Batch 12,160  of  14,625.    Elapsed: 0:13:13.
#   Batch 12,200  of  14,625.    Elapsed: 0:13:16.
#   Batch 12,240  of  14,625.    Elapsed: 0:13:18.
#   Batch 12,280  of  14,625.    Elapsed: 0:13:21.
#   Batch 12,320  of  14,625.    Elapsed: 0:13:24.
#   Batch 12,360  of  14,625.    Elapsed: 0:13:26.
#   Batch 12,400  of  14,625.    Elapsed: 0:13:29.
#   Batch 12,440  of  14,625.    Elapsed: 0:13:32.
#   Batch 12,480  of  14,625.    Elapsed: 0:13:34.
#   Batch 12,520  of  14,625.    Elapsed: 0:13:37.
#   Batch 12,560  of  14,625.    Elapsed: 0:13:39.
#   Batch 12,600  of  14,625.    Elapsed: 0:13:42.
#   Batch 12,640  of  14,625.    Elapsed: 0:13:45.
#   Batch 12,680  of  14,625.    Elapsed: 0:13:47.
#   Batch 12,720  of  14,625.    Elapsed: 0:13:50.
#   Batch 12,760  of  14,625.    Elapsed: 0:13:52.
#   Batch 12,800  of  14,625.    Elapsed: 0:13:55.
#   Batch 12,840  of  14,625.    Elapsed: 0:13:58.
#   Batch 12,880  of  14,625.    Elapsed: 0:14:00.
#   Batch 12,920  of  14,625.    Elapsed: 0:14:03.
#   Batch 12,960  of  14,625.    Elapsed: 0:14:05.
#   Batch 13,000  of  14,625.    Elapsed: 0:14:08.
#   Batch 13,040  of  14,625.    Elapsed: 0:14:11.
#   Batch 13,080  of  14,625.    Elapsed: 0:14:13.
#   Batch 13,120  of  14,625.    Elapsed: 0:14:16.
#   Batch 13,160  of  14,625.    Elapsed: 0:14:18.
#   Batch 13,200  of  14,625.    Elapsed: 0:14:21.
#   Batch 13,240  of  14,625.    Elapsed: 0:14:24.
#   Batch 13,280  of  14,625.    Elapsed: 0:14:26.
#   Batch 13,320  of  14,625.    Elapsed: 0:14:29.
#   Batch 13,360  of  14,625.    Elapsed: 0:14:32.
#   Batch 13,400  of  14,625.    Elapsed: 0:14:34.
#   Batch 13,440  of  14,625.    Elapsed: 0:14:37.
#   Batch 13,480  of  14,625.    Elapsed: 0:14:39.
#   Batch 13,520  of  14,625.    Elapsed: 0:14:42.
#   Batch 13,560  of  14,625.    Elapsed: 0:14:45.
#   Batch 13,600  of  14,625.    Elapsed: 0:14:47.
#   Batch 13,640  of  14,625.    Elapsed: 0:14:50.
#   Batch 13,680  of  14,625.    Elapsed: 0:14:52.
#   Batch 13,720  of  14,625.    Elapsed: 0:14:55.
#   Batch 13,760  of  14,625.    Elapsed: 0:14:58.
#   Batch 13,800  of  14,625.    Elapsed: 0:15:00.
#   Batch 13,840  of  14,625.    Elapsed: 0:15:03.
#   Batch 13,880  of  14,625.    Elapsed: 0:15:05.
#   Batch 13,920  of  14,625.    Elapsed: 0:15:08.
#   Batch 13,960  of  14,625.    Elapsed: 0:15:11.
#   Batch 14,000  of  14,625.    Elapsed: 0:15:13.
#   Batch 14,040  of  14,625.    Elapsed: 0:15:16.
#   Batch 14,080  of  14,625.    Elapsed: 0:15:18.
#   Batch 14,120  of  14,625.    Elapsed: 0:15:21.
#   Batch 14,160  of  14,625.    Elapsed: 0:15:24.
#   Batch 14,200  of  14,625.    Elapsed: 0:15:26.
#   Batch 14,240  of  14,625.    Elapsed: 0:15:29.
#   Batch 14,280  of  14,625.    Elapsed: 0:15:31.
#   Batch 14,320  of  14,625.    Elapsed: 0:15:34.
#   Batch 14,360  of  14,625.    Elapsed: 0:15:37.
#   Batch 14,400  of  14,625.    Elapsed: 0:15:39.
#   Batch 14,440  of  14,625.    Elapsed: 0:15:42.
#   Batch 14,480  of  14,625.    Elapsed: 0:15:44.
#   Batch 14,520  of  14,625.    Elapsed: 0:15:47.
#   Batch 14,560  of  14,625.    Elapsed: 0:15:50.
#   Batch 14,600  of  14,625.    Elapsed: 0:15:52.
#
#   Average training loss: 0.32
#   Training epoch took: 0:15:54
#
# ======== Epoch 2 / 2 ========
# Training...
#   Batch    40  of  14,625.    Elapsed: 0:00:03.
#   Batch    80  of  14,625.    Elapsed: 0:00:05.
#   Batch   120  of  14,625.    Elapsed: 0:00:08.
#   Batch   160  of  14,625.    Elapsed: 0:00:10.
#   Batch   200  of  14,625.    Elapsed: 0:00:13.
#   Batch   240  of  14,625.    Elapsed: 0:00:16.
#   Batch   280  of  14,625.    Elapsed: 0:00:18.
#   Batch   320  of  14,625.    Elapsed: 0:00:21.
#   Batch   360  of  14,625.    Elapsed: 0:00:23.
#   Batch   400  of  14,625.    Elapsed: 0:00:26.
#   Batch   440  of  14,625.    Elapsed: 0:00:29.
#   Batch   480  of  14,625.    Elapsed: 0:00:31.
#   Batch   520  of  14,625.    Elapsed: 0:00:34.
#   Batch   560  of  14,625.    Elapsed: 0:00:36.
#   Batch   600  of  14,625.    Elapsed: 0:00:39.
#   Batch   640  of  14,625.    Elapsed: 0:00:42.
#   Batch   680  of  14,625.    Elapsed: 0:00:44.
#   Batch   720  of  14,625.    Elapsed: 0:00:47.
#   Batch   760  of  14,625.    Elapsed: 0:00:49.
#   Batch   800  of  14,625.    Elapsed: 0:00:52.
#   Batch   840  of  14,625.    Elapsed: 0:00:55.
#   Batch   880  of  14,625.    Elapsed: 0:00:57.
#   Batch   920  of  14,625.    Elapsed: 0:01:00.
#   Batch   960  of  14,625.    Elapsed: 0:01:03.
#   Batch 1,000  of  14,625.    Elapsed: 0:01:05.
#   Batch 1,040  of  14,625.    Elapsed: 0:01:08.
#   Batch 1,080  of  14,625.    Elapsed: 0:01:10.
#   Batch 1,120  of  14,625.    Elapsed: 0:01:13.
#   Batch 1,160  of  14,625.    Elapsed: 0:01:16.
#   Batch 1,200  of  14,625.    Elapsed: 0:01:18.
#   Batch 1,240  of  14,625.    Elapsed: 0:01:21.
#   Batch 1,280  of  14,625.    Elapsed: 0:01:23.
#   Batch 1,320  of  14,625.    Elapsed: 0:01:26.
#   Batch 1,360  of  14,625.    Elapsed: 0:01:29.
#   Batch 1,400  of  14,625.    Elapsed: 0:01:31.
#   Batch 1,440  of  14,625.    Elapsed: 0:01:34.
#   Batch 1,480  of  14,625.    Elapsed: 0:01:36.
#   Batch 1,520  of  14,625.    Elapsed: 0:01:39.
#   Batch 1,560  of  14,625.    Elapsed: 0:01:42.
#   Batch 1,600  of  14,625.    Elapsed: 0:01:44.
#   Batch 1,640  of  14,625.    Elapsed: 0:01:47.
#   Batch 1,680  of  14,625.    Elapsed: 0:01:49.
#   Batch 1,720  of  14,625.    Elapsed: 0:01:52.
#   Batch 1,760  of  14,625.    Elapsed: 0:01:55.
#   Batch 1,800  of  14,625.    Elapsed: 0:01:57.
#   Batch 1,840  of  14,625.    Elapsed: 0:02:00.
#   Batch 1,880  of  14,625.    Elapsed: 0:02:02.
#   Batch 1,920  of  14,625.    Elapsed: 0:02:05.
#   Batch 1,960  of  14,625.    Elapsed: 0:02:08.
#   Batch 2,000  of  14,625.    Elapsed: 0:02:10.
#   Batch 2,040  of  14,625.    Elapsed: 0:02:13.
#   Batch 2,080  of  14,625.    Elapsed: 0:02:15.
#   Batch 2,120  of  14,625.    Elapsed: 0:02:18.
#   Batch 2,160  of  14,625.    Elapsed: 0:02:21.
#   Batch 2,200  of  14,625.    Elapsed: 0:02:23.
#   Batch 2,240  of  14,625.    Elapsed: 0:02:26.
#   Batch 2,280  of  14,625.    Elapsed: 0:02:28.
#   Batch 2,320  of  14,625.    Elapsed: 0:02:31.
#   Batch 2,360  of  14,625.    Elapsed: 0:02:34.
#   Batch 2,400  of  14,625.    Elapsed: 0:02:36.
#   Batch 2,440  of  14,625.    Elapsed: 0:02:39.
#   Batch 2,480  of  14,625.    Elapsed: 0:02:41.
#   Batch 2,520  of  14,625.    Elapsed: 0:02:44.
#   Batch 2,560  of  14,625.    Elapsed: 0:02:47.
#   Batch 2,600  of  14,625.    Elapsed: 0:02:49.
#   Batch 2,640  of  14,625.    Elapsed: 0:02:52.
#   Batch 2,680  of  14,625.    Elapsed: 0:02:54.
#   Batch 2,720  of  14,625.    Elapsed: 0:02:57.
#   Batch 2,760  of  14,625.    Elapsed: 0:03:00.
#   Batch 2,800  of  14,625.    Elapsed: 0:03:02.
#   Batch 2,840  of  14,625.    Elapsed: 0:03:05.
#   Batch 2,880  of  14,625.    Elapsed: 0:03:07.
#   Batch 2,920  of  14,625.    Elapsed: 0:03:10.
#   Batch 2,960  of  14,625.    Elapsed: 0:03:13.
#   Batch 3,000  of  14,625.    Elapsed: 0:03:15.
#   Batch 3,040  of  14,625.    Elapsed: 0:03:18.
#   Batch 3,080  of  14,625.    Elapsed: 0:03:20.
#   Batch 3,120  of  14,625.    Elapsed: 0:03:23.
#   Batch 3,160  of  14,625.    Elapsed: 0:03:26.
#   Batch 3,200  of  14,625.    Elapsed: 0:03:28.
#   Batch 3,240  of  14,625.    Elapsed: 0:03:31.
#   Batch 3,280  of  14,625.    Elapsed: 0:03:33.
#   Batch 3,320  of  14,625.    Elapsed: 0:03:36.
#   Batch 3,360  of  14,625.    Elapsed: 0:03:39.
#   Batch 3,400  of  14,625.    Elapsed: 0:03:41.
#   Batch 3,440  of  14,625.    Elapsed: 0:03:44.
#   Batch 3,480  of  14,625.    Elapsed: 0:03:46.
#   Batch 3,520  of  14,625.    Elapsed: 0:03:49.
#   Batch 3,560  of  14,625.    Elapsed: 0:03:52.
#   Batch 3,600  of  14,625.    Elapsed: 0:03:54.
#   Batch 3,640  of  14,625.    Elapsed: 0:03:57.
#   Batch 3,680  of  14,625.    Elapsed: 0:04:00.
#   Batch 3,720  of  14,625.    Elapsed: 0:04:02.
#   Batch 3,760  of  14,625.    Elapsed: 0:04:05.
#   Batch 3,800  of  14,625.    Elapsed: 0:04:07.
#   Batch 3,840  of  14,625.    Elapsed: 0:04:10.
#   Batch 3,880  of  14,625.    Elapsed: 0:04:13.
#   Batch 3,920  of  14,625.    Elapsed: 0:04:15.
#   Batch 3,960  of  14,625.    Elapsed: 0:04:18.
#   Batch 4,000  of  14,625.    Elapsed: 0:04:20.
#   Batch 4,040  of  14,625.    Elapsed: 0:04:23.
#   Batch 4,080  of  14,625.    Elapsed: 0:04:26.
#   Batch 4,120  of  14,625.    Elapsed: 0:04:28.
#   Batch 4,160  of  14,625.    Elapsed: 0:04:31.
#   Batch 4,200  of  14,625.    Elapsed: 0:04:33.
#   Batch 4,240  of  14,625.    Elapsed: 0:04:36.
#   Batch 4,280  of  14,625.    Elapsed: 0:04:39.
#   Batch 4,320  of  14,625.    Elapsed: 0:04:41.
#   Batch 4,360  of  14,625.    Elapsed: 0:04:44.
#   Batch 4,400  of  14,625.    Elapsed: 0:04:46.
#   Batch 4,440  of  14,625.    Elapsed: 0:04:49.
#   Batch 4,480  of  14,625.    Elapsed: 0:04:52.
#   Batch 4,520  of  14,625.    Elapsed: 0:04:54.
#   Batch 4,560  of  14,625.    Elapsed: 0:04:57.
#   Batch 4,600  of  14,625.    Elapsed: 0:04:59.
#   Batch 4,640  of  14,625.    Elapsed: 0:05:02.
#   Batch 4,680  of  14,625.    Elapsed: 0:05:05.
#   Batch 4,720  of  14,625.    Elapsed: 0:05:07.
#   Batch 4,760  of  14,625.    Elapsed: 0:05:10.
#   Batch 4,800  of  14,625.    Elapsed: 0:05:13.
#   Batch 4,840  of  14,625.    Elapsed: 0:05:15.
#   Batch 4,880  of  14,625.    Elapsed: 0:05:18.
#   Batch 4,920  of  14,625.    Elapsed: 0:05:20.
#   Batch 4,960  of  14,625.    Elapsed: 0:05:23.
#   Batch 5,000  of  14,625.    Elapsed: 0:05:26.
#   Batch 5,040  of  14,625.    Elapsed: 0:05:28.
#   Batch 5,080  of  14,625.    Elapsed: 0:05:31.
#   Batch 5,120  of  14,625.    Elapsed: 0:05:33.
#   Batch 5,160  of  14,625.    Elapsed: 0:05:36.
#   Batch 5,200  of  14,625.    Elapsed: 0:05:39.
#   Batch 5,240  of  14,625.    Elapsed: 0:05:41.
#   Batch 5,280  of  14,625.    Elapsed: 0:05:44.
#   Batch 5,320  of  14,625.    Elapsed: 0:05:46.
#   Batch 5,360  of  14,625.    Elapsed: 0:05:49.
#   Batch 5,400  of  14,625.    Elapsed: 0:05:52.
#   Batch 5,440  of  14,625.    Elapsed: 0:05:54.
#   Batch 5,480  of  14,625.    Elapsed: 0:05:57.
#   Batch 5,520  of  14,625.    Elapsed: 0:05:59.
#   Batch 5,560  of  14,625.    Elapsed: 0:06:02.
#   Batch 5,600  of  14,625.    Elapsed: 0:06:05.
#   Batch 5,640  of  14,625.    Elapsed: 0:06:07.
#   Batch 5,680  of  14,625.    Elapsed: 0:06:10.
#   Batch 5,720  of  14,625.    Elapsed: 0:06:12.
#   Batch 5,760  of  14,625.    Elapsed: 0:06:15.
#   Batch 5,800  of  14,625.    Elapsed: 0:06:18.
#   Batch 5,840  of  14,625.    Elapsed: 0:06:20.
#   Batch 5,880  of  14,625.    Elapsed: 0:06:23.
#   Batch 5,920  of  14,625.    Elapsed: 0:06:25.
#   Batch 5,960  of  14,625.    Elapsed: 0:06:28.
#   Batch 6,000  of  14,625.    Elapsed: 0:06:31.
#   Batch 6,040  of  14,625.    Elapsed: 0:06:33.
#   Batch 6,080  of  14,625.    Elapsed: 0:06:36.
#   Batch 6,120  of  14,625.    Elapsed: 0:06:39.
#   Batch 6,160  of  14,625.    Elapsed: 0:06:41.
#   Batch 6,200  of  14,625.    Elapsed: 0:06:44.
#   Batch 6,240  of  14,625.    Elapsed: 0:06:46.
#   Batch 6,280  of  14,625.    Elapsed: 0:06:49.
#   Batch 6,320  of  14,625.    Elapsed: 0:06:52.
#   Batch 6,360  of  14,625.    Elapsed: 0:06:54.
#   Batch 6,400  of  14,625.    Elapsed: 0:06:57.
#   Batch 6,440  of  14,625.    Elapsed: 0:06:59.
#   Batch 6,480  of  14,625.    Elapsed: 0:07:02.
#   Batch 6,520  of  14,625.    Elapsed: 0:07:05.
#   Batch 6,560  of  14,625.    Elapsed: 0:07:07.
#   Batch 6,600  of  14,625.    Elapsed: 0:07:10.
#   Batch 6,640  of  14,625.    Elapsed: 0:07:12.
#   Batch 6,680  of  14,625.    Elapsed: 0:07:15.
#   Batch 6,720  of  14,625.    Elapsed: 0:07:18.
#   Batch 6,760  of  14,625.    Elapsed: 0:07:20.
#   Batch 6,800  of  14,625.    Elapsed: 0:07:23.
#   Batch 6,840  of  14,625.    Elapsed: 0:07:25.
#   Batch 6,880  of  14,625.    Elapsed: 0:07:28.
#   Batch 6,920  of  14,625.    Elapsed: 0:07:31.
#   Batch 6,960  of  14,625.    Elapsed: 0:07:33.
#   Batch 7,000  of  14,625.    Elapsed: 0:07:36.
#   Batch 7,040  of  14,625.    Elapsed: 0:07:39.
#   Batch 7,080  of  14,625.    Elapsed: 0:07:41.
#   Batch 7,120  of  14,625.    Elapsed: 0:07:44.
#   Batch 7,160  of  14,625.    Elapsed: 0:07:46.
#   Batch 7,200  of  14,625.    Elapsed: 0:07:49.
#   Batch 7,240  of  14,625.    Elapsed: 0:07:52.
#   Batch 7,280  of  14,625.    Elapsed: 0:07:54.
#   Batch 7,320  of  14,625.    Elapsed: 0:07:57.
#   Batch 7,360  of  14,625.    Elapsed: 0:07:59.
#   Batch 7,400  of  14,625.    Elapsed: 0:08:02.
#   Batch 7,440  of  14,625.    Elapsed: 0:08:05.
#   Batch 7,480  of  14,625.    Elapsed: 0:08:07.
#   Batch 7,520  of  14,625.    Elapsed: 0:08:10.
#   Batch 7,560  of  14,625.    Elapsed: 0:08:12.
#   Batch 7,600  of  14,625.    Elapsed: 0:08:15.
#   Batch 7,640  of  14,625.    Elapsed: 0:08:18.
#   Batch 7,680  of  14,625.    Elapsed: 0:08:20.
#   Batch 7,720  of  14,625.    Elapsed: 0:08:23.
#   Batch 7,760  of  14,625.    Elapsed: 0:08:25.
#   Batch 7,800  of  14,625.    Elapsed: 0:08:28.
#   Batch 7,840  of  14,625.    Elapsed: 0:08:31.
#   Batch 7,880  of  14,625.    Elapsed: 0:08:33.
#   Batch 7,920  of  14,625.    Elapsed: 0:08:36.
#   Batch 7,960  of  14,625.    Elapsed: 0:08:38.
#   Batch 8,000  of  14,625.    Elapsed: 0:08:41.
#   Batch 8,040  of  14,625.    Elapsed: 0:08:44.
#   Batch 8,080  of  14,625.    Elapsed: 0:08:46.
#   Batch 8,120  of  14,625.    Elapsed: 0:08:49.
#   Batch 8,160  of  14,625.    Elapsed: 0:08:51.
#   Batch 8,200  of  14,625.    Elapsed: 0:08:54.
#   Batch 8,240  of  14,625.    Elapsed: 0:08:57.
#   Batch 8,280  of  14,625.    Elapsed: 0:08:59.
#   Batch 8,320  of  14,625.    Elapsed: 0:09:02.
#   Batch 8,360  of  14,625.    Elapsed: 0:09:04.
#   Batch 8,400  of  14,625.    Elapsed: 0:09:07.
#   Batch 8,440  of  14,625.    Elapsed: 0:09:10.
#   Batch 8,480  of  14,625.    Elapsed: 0:09:12.
#   Batch 8,520  of  14,625.    Elapsed: 0:09:15.
#   Batch 8,560  of  14,625.    Elapsed: 0:09:17.
#   Batch 8,600  of  14,625.    Elapsed: 0:09:20.
#   Batch 8,640  of  14,625.    Elapsed: 0:09:23.
#   Batch 8,680  of  14,625.    Elapsed: 0:09:25.
#   Batch 8,720  of  14,625.    Elapsed: 0:09:28.
#   Batch 8,760  of  14,625.    Elapsed: 0:09:30.
#   Batch 8,800  of  14,625.    Elapsed: 0:09:33.
#   Batch 8,840  of  14,625.    Elapsed: 0:09:36.
#   Batch 8,880  of  14,625.    Elapsed: 0:09:38.
#   Batch 8,920  of  14,625.    Elapsed: 0:09:41.
#   Batch 8,960  of  14,625.    Elapsed: 0:09:44.
#   Batch 9,000  of  14,625.    Elapsed: 0:09:46.
#   Batch 9,040  of  14,625.    Elapsed: 0:09:49.
#   Batch 9,080  of  14,625.    Elapsed: 0:09:51.
#   Batch 9,120  of  14,625.    Elapsed: 0:09:54.
#   Batch 9,160  of  14,625.    Elapsed: 0:09:57.
#   Batch 9,200  of  14,625.    Elapsed: 0:09:59.
#   Batch 9,240  of  14,625.    Elapsed: 0:10:02.
#   Batch 9,280  of  14,625.    Elapsed: 0:10:04.
#   Batch 9,320  of  14,625.    Elapsed: 0:10:07.
#   Batch 9,360  of  14,625.    Elapsed: 0:10:10.
#   Batch 9,400  of  14,625.    Elapsed: 0:10:12.
#   Batch 9,440  of  14,625.    Elapsed: 0:10:15.
#   Batch 9,480  of  14,625.    Elapsed: 0:10:17.
#   Batch 9,520  of  14,625.    Elapsed: 0:10:20.
#   Batch 9,560  of  14,625.    Elapsed: 0:10:23.
#   Batch 9,600  of  14,625.    Elapsed: 0:10:25.
#   Batch 9,640  of  14,625.    Elapsed: 0:10:28.
#   Batch 9,680  of  14,625.    Elapsed: 0:10:30.
#   Batch 9,720  of  14,625.    Elapsed: 0:10:33.
#   Batch 9,760  of  14,625.    Elapsed: 0:10:36.
#   Batch 9,800  of  14,625.    Elapsed: 0:10:38.
#   Batch 9,840  of  14,625.    Elapsed: 0:10:41.
#   Batch 9,880  of  14,625.    Elapsed: 0:10:43.
#   Batch 9,920  of  14,625.    Elapsed: 0:10:46.
#   Batch 9,960  of  14,625.    Elapsed: 0:10:49.
#   Batch 10,000  of  14,625.    Elapsed: 0:10:51.
#   Batch 10,040  of  14,625.    Elapsed: 0:10:54.
#   Batch 10,080  of  14,625.    Elapsed: 0:10:56.
#   Batch 10,120  of  14,625.    Elapsed: 0:10:59.
#   Batch 10,160  of  14,625.    Elapsed: 0:11:02.
#   Batch 10,200  of  14,625.    Elapsed: 0:11:04.
#   Batch 10,240  of  14,625.    Elapsed: 0:11:07.
#   Batch 10,280  of  14,625.    Elapsed: 0:11:09.
#   Batch 10,320  of  14,625.    Elapsed: 0:11:12.
#   Batch 10,360  of  14,625.    Elapsed: 0:11:15.
#   Batch 10,400  of  14,625.    Elapsed: 0:11:17.
#   Batch 10,440  of  14,625.    Elapsed: 0:11:20.
#   Batch 10,480  of  14,625.    Elapsed: 0:11:23.
#   Batch 10,520  of  14,625.    Elapsed: 0:11:25.
#   Batch 10,560  of  14,625.    Elapsed: 0:11:28.
#   Batch 10,600  of  14,625.    Elapsed: 0:11:30.
#   Batch 10,640  of  14,625.    Elapsed: 0:11:33.
#   Batch 10,680  of  14,625.    Elapsed: 0:11:36.
#   Batch 10,720  of  14,625.    Elapsed: 0:11:38.
#   Batch 10,760  of  14,625.    Elapsed: 0:11:41.
#   Batch 10,800  of  14,625.    Elapsed: 0:11:43.
#   Batch 10,840  of  14,625.    Elapsed: 0:11:46.
#   Batch 10,880  of  14,625.    Elapsed: 0:11:49.
#   Batch 10,920  of  14,625.    Elapsed: 0:11:51.
#   Batch 10,960  of  14,625.    Elapsed: 0:11:54.
#   Batch 11,000  of  14,625.    Elapsed: 0:11:56.
#   Batch 11,040  of  14,625.    Elapsed: 0:11:59.
#   Batch 11,080  of  14,625.    Elapsed: 0:12:02.
#   Batch 11,120  of  14,625.    Elapsed: 0:12:04.
#   Batch 11,160  of  14,625.    Elapsed: 0:12:07.
#   Batch 11,200  of  14,625.    Elapsed: 0:12:09.
#   Batch 11,240  of  14,625.    Elapsed: 0:12:12.
#   Batch 11,280  of  14,625.    Elapsed: 0:12:15.
#   Batch 11,320  of  14,625.    Elapsed: 0:12:17.
#   Batch 11,360  of  14,625.    Elapsed: 0:12:20.
#   Batch 11,400  of  14,625.    Elapsed: 0:12:22.
#   Batch 11,440  of  14,625.    Elapsed: 0:12:25.
#   Batch 11,480  of  14,625.    Elapsed: 0:12:28.
#   Batch 11,520  of  14,625.    Elapsed: 0:12:30.
#   Batch 11,560  of  14,625.    Elapsed: 0:12:33.
#   Batch 11,600  of  14,625.    Elapsed: 0:12:36.
#   Batch 11,640  of  14,625.    Elapsed: 0:12:38.
#   Batch 11,680  of  14,625.    Elapsed: 0:12:41.
#   Batch 11,720  of  14,625.    Elapsed: 0:12:43.
#   Batch 11,760  of  14,625.    Elapsed: 0:12:46.
#   Batch 11,800  of  14,625.    Elapsed: 0:12:49.
#   Batch 11,840  of  14,625.    Elapsed: 0:12:51.
#   Batch 11,880  of  14,625.    Elapsed: 0:12:54.
#   Batch 11,920  of  14,625.    Elapsed: 0:12:56.
#   Batch 11,960  of  14,625.    Elapsed: 0:12:59.
#   Batch 12,000  of  14,625.    Elapsed: 0:13:02.
#   Batch 12,040  of  14,625.    Elapsed: 0:13:04.
#   Batch 12,080  of  14,625.    Elapsed: 0:13:07.
#   Batch 12,120  of  14,625.    Elapsed: 0:13:09.
#   Batch 12,160  of  14,625.    Elapsed: 0:13:12.
#   Batch 12,200  of  14,625.    Elapsed: 0:13:15.
#   Batch 12,240  of  14,625.    Elapsed: 0:13:17.
#   Batch 12,280  of  14,625.    Elapsed: 0:13:20.
#   Batch 12,320  of  14,625.    Elapsed: 0:13:22.
#   Batch 12,360  of  14,625.    Elapsed: 0:13:25.
#   Batch 12,400  of  14,625.    Elapsed: 0:13:28.
#   Batch 12,440  of  14,625.    Elapsed: 0:13:30.
#   Batch 12,480  of  14,625.    Elapsed: 0:13:33.
#   Batch 12,520  of  14,625.    Elapsed: 0:13:36.
#   Batch 12,560  of  14,625.    Elapsed: 0:13:38.
#   Batch 12,600  of  14,625.    Elapsed: 0:13:41.
#   Batch 12,640  of  14,625.    Elapsed: 0:13:43.
#   Batch 12,680  of  14,625.    Elapsed: 0:13:46.
#   Batch 12,720  of  14,625.    Elapsed: 0:13:49.
#   Batch 12,760  of  14,625.    Elapsed: 0:13:51.
#   Batch 12,800  of  14,625.    Elapsed: 0:13:54.
#   Batch 12,840  of  14,625.    Elapsed: 0:13:56.
#   Batch 12,880  of  14,625.    Elapsed: 0:13:59.
#   Batch 12,920  of  14,625.    Elapsed: 0:14:02.
#   Batch 12,960  of  14,625.    Elapsed: 0:14:04.
#   Batch 13,000  of  14,625.    Elapsed: 0:14:07.
#   Batch 13,040  of  14,625.    Elapsed: 0:14:09.
#   Batch 13,080  of  14,625.    Elapsed: 0:14:12.
#   Batch 13,120  of  14,625.    Elapsed: 0:14:15.
#   Batch 13,160  of  14,625.    Elapsed: 0:14:17.
#   Batch 13,200  of  14,625.    Elapsed: 0:14:20.
#   Batch 13,240  of  14,625.    Elapsed: 0:14:22.
#   Batch 13,280  of  14,625.    Elapsed: 0:14:25.
#   Batch 13,320  of  14,625.    Elapsed: 0:14:28.
#   Batch 13,360  of  14,625.    Elapsed: 0:14:30.
#   Batch 13,400  of  14,625.    Elapsed: 0:14:33.
#   Batch 13,440  of  14,625.    Elapsed: 0:14:35.
#   Batch 13,480  of  14,625.    Elapsed: 0:14:38.
#   Batch 13,520  of  14,625.    Elapsed: 0:14:41.
#   Batch 13,560  of  14,625.    Elapsed: 0:14:43.
#   Batch 13,600  of  14,625.    Elapsed: 0:14:46.
#   Batch 13,640  of  14,625.    Elapsed: 0:14:49.
#   Batch 13,680  of  14,625.    Elapsed: 0:14:51.
#   Batch 13,720  of  14,625.    Elapsed: 0:14:54.
#   Batch 13,760  of  14,625.    Elapsed: 0:14:56.
#   Batch 13,800  of  14,625.    Elapsed: 0:14:59.
#   Batch 13,840  of  14,625.    Elapsed: 0:15:02.
#   Batch 13,880  of  14,625.    Elapsed: 0:15:04.
#   Batch 13,920  of  14,625.    Elapsed: 0:15:07.
#   Batch 13,960  of  14,625.    Elapsed: 0:15:09.
#   Batch 14,000  of  14,625.    Elapsed: 0:15:12.
#   Batch 14,040  of  14,625.    Elapsed: 0:15:15.
#   Batch 14,080  of  14,625.    Elapsed: 0:15:17.
#   Batch 14,120  of  14,625.    Elapsed: 0:15:20.
#   Batch 14,160  of  14,625.    Elapsed: 0:15:22.
#   Batch 14,200  of  14,625.    Elapsed: 0:15:25.
#   Batch 14,240  of  14,625.    Elapsed: 0:15:28.
#   Batch 14,280  of  14,625.    Elapsed: 0:15:30.
#   Batch 14,320  of  14,625.    Elapsed: 0:15:33.
#   Batch 14,360  of  14,625.    Elapsed: 0:15:35.
#   Batch 14,400  of  14,625.    Elapsed: 0:15:38.
#   Batch 14,440  of  14,625.    Elapsed: 0:15:41.
#   Batch 14,480  of  14,625.    Elapsed: 0:15:43.
#   Batch 14,520  of  14,625.    Elapsed: 0:15:46.
#   Batch 14,560  of  14,625.    Elapsed: 0:15:48.
#   Batch 14,600  of  14,625.    Elapsed: 0:15:51.
#
#   Average training loss: 0.23
#   Training epoch took: 0:15:53
#
# Training complete!

# %%
model.eval()

predictions, true_labels = [], []

# load test cases into GPU in batches
for batch in test_loader:
    batch = {k: v.to(device) for k, v in batch.items()}

    with torch.no_grad():
        outputs = model(**batch)

    logits = outputs.logits
    logits = logits.detach().cpu().numpy()
    label_ids = batch['labels'].to('cpu').numpy()

    predictions.append(logits)
    true_labels.append(label_ids)

predictions = np.argmax(np.concatenate(predictions, axis=0), axis=1)
true_labels = np.concatenate(true_labels, axis=0)

accuracy = accuracy_score(true_labels, predictions)
print("Accuracy:", accuracy)

precision, recall, f1, _ = precision_recall_fscore_support(true_labels, predictions, average='weighted')
print(f"Precision: {precision}\nRecall: {recall}\nF1 Score: {f1}")
# Out:
# Accuracy: 0.9452361563517915
# Precision: 0.94519695511975
# Recall: 0.9452361563517915
# F1 Score: 0.9451319628607912

# %%
model_save_path = "/content/drive/MyDrive/CS4248/model_roberta.pth"
optimizer_save_path = "/content/drive/MyDrive/CS4248/model_roberta_optimizer.pth"

# Save the model, optimizer and encodings state
torch.save(model.state_dict(), model_save_path)
torch.save(optimizer.state_dict(), optimizer_save_path)
