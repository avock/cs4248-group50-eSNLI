# %%
import pandas as pd
import time, datetime, numpy as np
from transformers import BertTokenizer, BertForSequenceClassification
from transformers_interpret import SequenceClassificationExplainer
import torch
from torch.utils.data import Dataset, DataLoader
import time

# %%
test = pd.read_csv('path_to_test_csv')

# %%
def select_cols(df, col_list):
    '''
    Select columns from a dataframe
    '''
    return df[col_list]

def combine_sentences(df, col_list):

    results_df = df.copy()

    results_df['combined_text'] = '[CLS]' + results_df[col_list].astype(str).agg('[SEP]'.join, axis=1)

    return results_df

# %%
#Choose the target columns

target_cols = ['Sentence1', 'Sentence2', 'Explanation_1', 'gold_label'] # Premise, Hypothesis, Explanation
# target_cols = ['Sentence1', 'Sentence2', 'gold_label'] # Premise, Hypothesis
# target_cols = ['Sentence2', 'Sentence1', 'gold_label'] # Hypothesis, Premise
# target_cols = ['Sentence1', 'Explanation_1', 'Sentence2', 'gold_label'] # Premise, Explanation, Hypothesis
# target_cols = ['Sentence2', 'Explanation_1', 'Sentence1', 'gold_label'] # Hypothesis, Explanation, Premise

test_df = select_cols(test, target_cols)

# %%
test_df = combine_sentences(test_df, target_cols[:-1])

lables = {
    'entailment': 0,
    'neutral': 1,
    'contradiction': 2
}

test_df['labels'] = test_df['gold_label'].map(lables)

# %%
test_annotated = pd.read_csv('path_to_test_csv')
test_df["highlight_premise"] = test_annotated["Sentence1_marked_1"]
test_df["highlight_hypothesis"] = test_annotated["Sentence2_marked_1"]

# %%
test_df.head(2)
# Out:
#                                            Sentence1  \
# 0  This church choir sings to the masses as they ...
# 1  This church choir sings to the masses as they ...
#
#                                Sentence2  \
# 0  The church has cracks in the ceiling.
# 1        The church is filled with song.
#
#                                        Explanation_1  gold_label  \
# 0        Not all churches have cracks in the ceiling     neutral
# 1  "Filled with song" is a rephrasing of the "cho...  entailment
#
#                                        combined_text  labels  \
# 0  [CLS]This church choir sings to the masses as ...       1
# 1  [CLS]This church choir sings to the masses as ...       0
#
#                                    highlight_premise  \
# 0  This church choir sings to the masses as they ...
# 1   This church *choir* *sings* *to* *the* *masse...
#
#                              highlight_hypothesis
# 0   The church has *cracks* *in* *the* *ceiling.*
# 1           The church is *filled* *with* *song.*

# %%
test_df['combined_text'][0]
# Out:
# '[CLS]This church choir sings to the masses as they sing joyous songs from the book at a church.[SEP]The church has cracks in the ceiling.[SEP]Not all churches have cracks in the ceiling'

# %%
# Setup device and tokenizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# Initialize the model
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased",
    num_labels=3,
    output_attentions=True,
    output_hidden_states=False
)

#unfreezing layer 11 and the classifier. note: the pooler is still frozen
for name, param in model.named_parameters():
    if 'classifier' not in name and '11' not in name:
        param.requires_grad = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=3, bias=True)
# )

# %%
# model_type = 'premise_hypothesis_explanation'
model_type = 'model_v1'
# model_type = 'hypothesis_premise'
# model_type = 'premise_explanation_hypothesis'
# model_type = 'hypothesis_explanation_premise'

model_save_path = f"path_to_model_weights"

model.load_state_dict(torch.load(model_save_path))
# Out:
# <All keys matched successfully>

# %%
test_df['combined_text'][0]
# Out:
# '[CLS]This church choir sings to the masses as they sing joyous songs from the book at a church.[SEP]The church has cracks in the ceiling.[SEP]Not all churches have cracks in the ceiling'

# %%
def extract_marked_token_attributions(version1, version2):
    index_1 = 0
    index_2 = 0
    desired_version = []
    for i in range(len(version2)):
      if index_1 < len(version1):
        if version1[index_1][0] != '*':
          index_1 += 1
          index_2 += 1
        else:
          index_1 += 1
          while version1[index_1][0] != '*':
            desired_version.append(version2[index_2])
            index_1 += 1
            index_2 += 1
          index_1 += 1

    return desired_version

# %%
from transformers_interpret import SequenceClassificationExplainer

def compute_segment_attributions(df, model, tokenizer):
    cls_explainer = SequenceClassificationExplainer(model, tokenizer)
    results = []

    for index, row in df.iterrows():
        text = row['combined_text']
        true_label = row['labels']
        highlight_premise = row['highlight_premise']
        highlight_hypothesis = row['highlight_hypothesis']

        text = text.replace("[CLS]", "").replace("[SEP]", "")
        print(f"\nProcessing index {index} with text: {text}")
        full_attributions = cls_explainer(text)

        if cls_explainer.predicted_class_index == true_label:
          annotated_attributions = cls_explainer(highlight_premise + " " + highlight_hypothesis) # premise before hypothesis (change order if input order is changed)

          desired_attributions = extract_marked_token_attributions(annotated_attributions, full_attributions)

          desired_attribution_score = 0
          total_positive_attribution_score = 0

          for pair in desired_attributions:
            print(f"Annotated Word: {pair[0]}\nAttribution: {pair[1]}")
            print("====================================================")
            desired_attribution_score += pair[1]

          for pair in full_attributions:
            if pair[1] > 0:
              total_positive_attribution_score += pair[1]

          print(f"Total Desired Attribution: {desired_attribution_score}")
          print(f"Total Attribution Score: {total_positive_attribution_score}")
          print(f"Test Case Score: {desired_attribution_score/total_positive_attribution_score}")

          results.append(desired_attribution_score/total_positive_attribution_score)

    return results

# Format is [CLS] Premise [SEP] Hypothesis [SEP] anything else
# VERY IMPORTANT: IT MUST BE PREMISE BEFORE HYPOTHESIS (if not then change the order where indicated)
results = compute_segment_attributions(test_df, model, tokenizer)
print("\nFinal Attribution results:", results)
# Out:
# Streaming output truncated to the last 5000 lines.
# Attribution: 0.2041970428374019
# ====================================================
# Annotated Word: in
# Attribution: 0.22068736939743888
# ====================================================
# Total Desired Attribution: 0.9903893866885354
# Total Attribution Score: 3.042191485358796
# Test Case Score: 0.3255512979557659
#
# Processing index 9528 with text: Several women in headscarves are standing in a cobbled courtyard.Several women wearing headscarves stand and talk to each other in a cobbled courtyard.
# Annotated Word: talk
# Attribution: -0.822270232815427
# ====================================================
# Annotated Word: to
# Attribution: -0.020640264935934724
# ====================================================
# Annotated Word: each
# Attribution: -0.15348131192078834
# ====================================================
# Annotated Word: other
# Attribution: -0.23142576561134484
# ====================================================
# Total Desired Attribution: -1.2278175752834948
# Total Attribution Score: 1.587453690691672
# Test Case Score: -0.7734509563857075
#
# Processing index 9529 with text: two young children wearing wool caps and mitten covering their mouths while whispering to each other.The children are yelling loudly.
#
# Processing index 9530 with text: two young children wearing wool caps and mitten covering their mouths while whispering to each other.Two young children are whispering to each other.
# Annotated Word: wearing
# Attribution: -0.02821206425484145
# ====================================================
# Annotated Word: wool
# Attribution: 0.03413666310488214
# ====================================================
# Annotated Word: caps
# Attribution: -0.0608614889095477
# ====================================================
# Annotated Word: young
# Attribution: 0.09861513166881879
# ====================================================
# Annotated Word: children
# Attribution: 0.1744442043740089
# ====================================================
# Total Desired Attribution: 0.21812244598332067
# Total Attribution Score: 3.092510943416206
# Test Case Score: 0.07053247344126364
#
# Processing index 9531 with text: two young children wearing wool caps and mitten covering their mouths while whispering to each other.They are whispering about their day.
# Annotated Word: whispering
# Attribution: 0.6018859628933563
# ====================================================
# Total Desired Attribution: 0.6018859628933563
# Total Attribution Score: 2.3561518638904824
# Test Case Score: 0.25545295790039657
#
# Processing index 9532 with text: A man in a black t-shirt and jeans in standing on the sidewalk looking at the camera as people walk by.There is a man running through a green field.
# Annotated Word: standing
# Attribution: 0.07126735271290219
# ====================================================
# Annotated Word: running
# Attribution: 0.1045779377084265
# ====================================================
# Total Desired Attribution: 0.17584529042132868
# Total Attribution Score: 2.219876918723365
# Test Case Score: 0.07921398206277852
#
# Processing index 9533 with text: A man in a black t-shirt and jeans in standing on the sidewalk looking at the camera as people walk by.The man is wearing designer fashions during a photoshoot.
# Annotated Word: wearing
# Attribution: 0.0665020374763675
# ====================================================
# Annotated Word: designer
# Attribution: 0.2975790563020598
# ====================================================
# Annotated Word: fashion
# Attribution: -0.03486144996344267
# ====================================================
# Annotated Word: ##s
# Attribution: -0.007360849922928247
# ====================================================
# Annotated Word: photos
# Attribution: 0.435598181959998
# ====================================================
# Annotated Word: ##hoot
# Attribution: 0.2609705484045436
# ====================================================
# Annotated Word: .
# Attribution: -0.0011773605054688542
# ====================================================
# Total Desired Attribution: 1.0172501637511293
# Total Attribution Score: 3.0447751432750434
# Test Case Score: 0.33409697461499477
#
# Processing index 9534 with text: A man in a black t-shirt and jeans in standing on the sidewalk looking at the camera as people walk by.There is a man in black outside on a busy sidewalk.
# Annotated Word: standing
# Attribution: 0.04047268457239027
# ====================================================
# Annotated Word: on
# Attribution: -0.001999567511696715
# ====================================================
# Annotated Word: the
# Attribution: -0.025403956490340437
# ====================================================
# Annotated Word: sidewalk
# Attribution: 0.15180770842123473
# ====================================================
# Annotated Word: people
# Attribution: 0.007907120398050986
# ====================================================
# Annotated Word: walk
# Attribution: 0.06373596424961327
# ====================================================
# Annotated Word: by
# Attribution: 0.01925723405267144
# ====================================================
# Annotated Word: .
# Attribution: 0.13875747642362932
# ====================================================
# Annotated Word: outside
# Attribution: -0.14960297153444868
# ====================================================
# Annotated Word: busy
# Attribution: -0.02173014952951953
# ====================================================
# Total Desired Attribution: 0.22320154305158463
# Total Attribution Score: 2.627883955208701
# Test Case Score: 0.084935844525851
#
# Processing index 9535 with text: A girl wearing black is riding a giant unicycle on the beach.The woman is naked
# Annotated Word: wearing
# Attribution: -0.011656475889410501
# ====================================================
# Annotated Word: black
# Attribution: -0.030549708198545585
# ====================================================
# Annotated Word: is
# Attribution: -0.32072057814274113
# ====================================================
# Annotated Word: naked
# Attribution: 0.8717546853374473
# ====================================================
# Total Desired Attribution: 0.5088279231067501
# Total Attribution Score: 1.498930181610267
# Test Case Score: 0.3394607229538388
#
# Processing index 9536 with text: A girl wearing black is riding a giant unicycle on the beach.The beach is cold
# Annotated Word: cold
# Attribution: 0.3439960699336453
# ====================================================
# Total Desired Attribution: 0.3439960699336453
# Total Attribution Score: 1.7564610572436667
# Test Case Score: 0.1958461125653776
#
# Processing index 9537 with text: A girl wearing black is riding a giant unicycle on the beach.The girl has clothes on
# Annotated Word: a
# Attribution: -0.039096517796305214
# ====================================================
# Annotated Word: girl
# Attribution: 0.0862967463246047
# ====================================================
# Annotated Word: wearing
# Attribution: 0.2462948106941934
# ====================================================
# Annotated Word: black
# Attribution: 0.08616886488122692
# ====================================================
# Annotated Word: has
# Attribution: 0.4479171399041707
# ====================================================
# Annotated Word: clothes
# Attribution: 0.46744543238525305
# ====================================================
# Annotated Word: on
# Attribution: -0.07428790257353401
# ====================================================
# Total Desired Attribution: 1.2207385738196095
# Total Attribution Score: 2.361492541981043
# Test Case Score: 0.5169351806614383
#
# Processing index 9538 with text: A short-haired man in a dark camouflage jacket plays the saxophone on a street corner while people look on in the background.a man plays a saxophone
# Annotated Word: plays
# Attribution: -0.008972490463126875
# ====================================================
# Annotated Word: the
# Attribution: -0.09394823265766866
# ====================================================
# Annotated Word: saxophone
# Attribution: 0.5143301671645308
# ====================================================
# Annotated Word: saxophone
# Attribution: -0.5750736490045145
# ====================================================
# Total Desired Attribution: -0.1636642049607792
# Total Attribution Score: 2.1731140854428324
# Test Case Score: -0.0753132134466047
#
# Processing index 9539 with text: A short-haired man in a dark camouflage jacket plays the saxophone on a street corner while people look on in the background.a man performs on the street for tips
# Annotated Word: for
# Attribution: 0.6140667867372217
# ====================================================
# Annotated Word: tips
# Attribution: -0.48265319669450235
# ====================================================
# Total Desired Attribution: 0.13141359004271935
# Total Attribution Score: 1.6992439944682731
# Test Case Score: 0.07733650403975166
#
# Processing index 9540 with text: A short-haired man in a dark camouflage jacket plays the saxophone on a street corner while people look on in the background.a man is eating a sandwich
# Annotated Word: plays
# Attribution: -0.016438036650507068
# ====================================================
# Annotated Word: the
# Attribution: -0.011804468524879284
# ====================================================
# Annotated Word: saxophone
# Attribution: 0.21591063785107276
# ====================================================
# Annotated Word: eating
# Attribution: 0.5206373616352477
# ====================================================
# Annotated Word: a
# Attribution: -0.26256557368311667
# ====================================================
# Annotated Word: sandwich
# Attribution: 0.7483431475192498
# ====================================================
# Total Desired Attribution: 1.194083068147067
# Total Attribution Score: 2.092846498323922
# Test Case Score: 0.5705545385690547
#
# Processing index 9541 with text: A large man is sitting in front of a fountain statue while talking on a phone.The man is in the fountain.
#
# Processing index 9542 with text: A large man is sitting in front of a fountain statue while talking on a phone.The fountain has running water.
# Annotated Word: running
# Attribution: 0.06743476323385267
# ====================================================
# Annotated Word: water
# Attribution: -0.6130382494056114
# ====================================================
# Annotated Word: .
# Attribution: -0.11179765114860904
# ====================================================
# Total Desired Attribution: -0.6574011373203678
# Total Attribution Score: 1.5236310726910185
# Test Case Score: -0.4314700251940084
#
# Processing index 9543 with text: A large man is sitting in front of a fountain statue while talking on a phone.The man is talking to someone.
# Annotated Word: talking
# Attribution: 0.4177388939544708
# ====================================================
# Annotated Word: phone
# Attribution: -0.027986944475979724
# ====================================================
# Annotated Word: .
# Attribution: 0.13548825969788178
# ====================================================
# Annotated Word: talking
# Attribution: 0.20249502363637129
# ====================================================
# Annotated Word: someone
# Attribution: 0.66430200521306
# ====================================================
# Annotated Word: .
# Attribution: 0.06641062805466699
# ====================================================
# Total Desired Attribution: 1.4584478660804712
# Total Attribution Score: 2.564720175218916
# Test Case Score: 0.5686576961387153
#
# Processing index 9544 with text: Two women are tending to their herd of animals including cows and goats near a building made primarily of stone.The women are next to a big elementary school
# Annotated Word: tending
# Attribution: 0.08776815584595467
# ====================================================
# Annotated Word: animals
# Attribution: 0.0906753324006056
# ====================================================
# Annotated Word: next
# Attribution: 0.2236017061824571
# ====================================================
# Annotated Word: school
# Attribution: 0.414156755726291
# ====================================================
# Total Desired Attribution: 0.8162019501553084
# Total Attribution Score: 3.028676077818209
# Test Case Score: 0.2694913319166446
#
# Processing index 9545 with text: Two women are tending to their herd of animals including cows and goats near a building made primarily of stone.The two women are taking care of a herd of animals
# Annotated Word: tending
# Attribution: 0.03508511555080834
# ====================================================
# Annotated Word: herd
# Attribution: 0.13861525174505643
# ====================================================
# Annotated Word: taking
# Attribution: -0.05016544522391839
# ====================================================
# Annotated Word: care
# Attribution: -0.06864452296175076
# ====================================================
# Annotated Word: herd
# Attribution: 0.07732155629966399
# ====================================================
# Total Desired Attribution: 0.1322119554098596
# Total Attribution Score: 2.122150673270533
# Test Case Score: 0.06230092758027514
#
# Processing index 9546 with text: Two women are tending to their herd of animals including cows and goats near a building made primarily of stone.The women are both farmers
# Annotated Word: farmers
# Attribution: 0.9342425879293167
# ====================================================
# Total Desired Attribution: 0.9342425879293167
# Total Attribution Score: 1.3627072948558279
# Test Case Score: 0.6855783273899315
#
# Processing index 9547 with text: A surfer showing off his talent in public using a man-made water machine.A man is cutting the grass.
# Annotated Word: surfer
# Attribution: 0.11664087816590481
# ====================================================
# Annotated Word: showing
# Attribution: -0.0742406005304297
# ====================================================
# Annotated Word: off
# Attribution: 0.11682170987820018
# ====================================================
# Annotated Word: water
# Attribution: -0.0023710804411654816
# ====================================================
# Annotated Word: cutting
# Attribution: 0.5106777560541244
# ====================================================
# Annotated Word: grass
# Attribution: -0.15274702788108332
# ====================================================
# Annotated Word: .
# Attribution: 0.0793870680823237
# ====================================================
# Total Desired Attribution: 0.5941687033278745
# Total Attribution Score: 2.689632166218145
# Test Case Score: 0.22091076645745467
#
# Processing index 9548 with text: A surfer showing off his talent in public using a man-made water machine.A surfer is in performing at a charity event.
# Annotated Word: charity
# Attribution: 0.7454069992335133
# ====================================================
# Total Desired Attribution: 0.7454069992335133
# Total Attribution Score: 1.8557731014324403
# Test Case Score: 0.4016692550711862
#
# Processing index 9549 with text: A Man is eating food next to a child on a bench.Man eating on a bench near a child.
# Annotated Word: next
# Attribution: -0.01680345697218357
# ====================================================
# Annotated Word: child
# Attribution: 0.13534937901744173
# ====================================================
# Annotated Word: near
# Attribution: 0.3231034244632394
# ====================================================
# Annotated Word: child
# Attribution: 0.4283608586434417
# ====================================================
# Annotated Word: .
# Attribution: 0.15137684130968415
# ====================================================
# Total Desired Attribution: 1.0213870464616235
# Total Attribution Score: 3.111215366319225
# Test Case Score: 0.3282919779577948
#
# Processing index 9550 with text: A Man is eating food next to a child on a bench.Man eating child.
#
# Processing index 9551 with text: A Man is eating food next to a child on a bench.Man eating his food while sitting with his daughter.
# Annotated Word: daughter
# Attribution: 0.42664609716001467
# ====================================================
# Annotated Word: .
# Attribution: -0.029632199430358105
# ====================================================
# Total Desired Attribution: 0.39701389772965656
# Total Attribution Score: 2.2850794717708776
# Test Case Score: 0.17374183376737487
#
# Processing index 9552 with text: A large African American man sitting on a camping chair.the large black man is running a race
#
# Processing index 9553 with text: A large African American man sitting on a camping chair.The large black man is relaxing in the chair
# Annotated Word: african
# Attribution: 0.20195775676019692
# ====================================================
# Annotated Word: american
# Attribution: 0.09416356107483696
# ====================================================
# Annotated Word: sitting
# Attribution: 0.006945291959719351
# ====================================================
# Annotated Word: black
# Attribution: -0.31942585568458104
# ====================================================
# Annotated Word: relaxing
# Attribution: 0.7573313636630458
# ====================================================
# Total Desired Attribution: 0.7409721177732179
# Total Attribution Score: 1.5907610963944456
# Test Case Score: 0.4657972334454716
#
# Processing index 9554 with text: A large African American man sitting on a camping chair.The large black man is relaxing in the chair and waiting for a steak
# Annotated Word: black
# Attribution: 0.19677479848274437
# ====================================================
# Annotated Word: man
# Attribution: -0.1900141796658053
# ====================================================
# Annotated Word: relaxing
# Attribution: -0.0782412463497577
# ====================================================
# Annotated Word: waiting
# Attribution: 0.28339961490058446
# ====================================================
# Annotated Word: for
# Attribution: 0.08946970084422978
# ====================================================
# Annotated Word: a
# Attribution: -0.34964125326280376
# ====================================================
# Annotated Word: steak
# Attribution: 0.29769329498236713
# ====================================================
# Total Desired Attribution: 0.24944072993155897
# Total Attribution Score: 2.422580001604275
# Test Case Score: 0.10296490921512394
#
# Processing index 9555 with text: A group of Asian men are sitting or standing around a small square table.Some men are eating dinner around a large round table.
#
# Processing index 9556 with text: A group of Asian men are sitting or standing around a small square table.Some men are gathered around a table.
# Annotated Word: group
# Attribution: -0.00661443222668859
# ====================================================
# Annotated Word: of
# Attribution: 0.02985258316467836
# ====================================================
# Annotated Word: men
# Attribution: 0.16169454592249272
# ====================================================
# Annotated Word: sitting
# Attribution: 0.050910449728542174
# ====================================================
# Annotated Word: or
# Attribution: -0.03138804875382269
# ====================================================
# Annotated Word: standing
# Attribution: 0.004324174106674429
# ====================================================
# Annotated Word: some
# Attribution: 0.31549914559020087
# ====================================================
# Annotated Word: men
# Attribution: 0.24249057380045533
# ====================================================
# Annotated Word: gathered
# Attribution: 0.37534546259896545
# ====================================================
# Total Desired Attribution: 1.142114453931498
# Total Attribution Score: 3.405869918635909
# Test Case Score: 0.3353370742911192
#
# Processing index 9557 with text: A group of Asian men are sitting or standing around a small square table.Some men are having a planning meeting in a room.
# Annotated Word: meeting
# Attribution: 0.5140311690647377
# ====================================================
# Total Desired Attribution: 0.5140311690647377
# Total Attribution Score: 2.550492568441486
# Test Case Score: 0.20154191995111106
#
# Processing index 9558 with text: A young male wearing a white shirt with a character outlined very darkly.A young male in a white shirt.
# Annotated Word: wearing
# Attribution: 0.12435266498291929
# ====================================================
# Annotated Word: a
# Attribution: -0.1615337446981481
# ====================================================
# Annotated Word: white
# Attribution: 0.5788222536513177
# ====================================================
# Annotated Word: shirt
# Attribution: -0.17090232020795673
# ====================================================
# Annotated Word: in
# Attribution: -0.004630454915156211
# ====================================================
# Annotated Word: a
# Attribution: 0.18846310106794684
# ====================================================
# Annotated Word: white
# Attribution: 0.6669906703224878
# ====================================================
# Annotated Word: shirt
# Attribution: -0.048448925107961324
# ====================================================
# Annotated Word: .
# Attribution: 0.08402254289920803
# ====================================================
# Total Desired Attribution: 1.2571357879946572
# Total Attribution Score: 2.179555210221672
# Test Case Score: 0.5767854753570568
#
# Processing index 9559 with text: A young male wearing a white shirt with a character outlined very darkly.A boy in a purple shirt.
# Annotated Word: white
# Attribution: 0.041902712444952445
# ====================================================
# Annotated Word: purple
# Attribution: 0.5672944836705093
# ====================================================
# Total Desired Attribution: 0.6091971961154617
# Total Attribution Score: 3.2439188811588267
# Test Case Score: 0.18779668001372402
#
# Processing index 9560 with text: A young male wearing a white shirt with a character outlined very darkly.A blonde boy in a white shirt.
#
# Processing index 9561 with text: A man and a woman walk at a flea market.The man and women are at a high priced store.
#
# Processing index 9562 with text: A man and a woman walk at a flea market.The deals can be found at flea markets.
# Annotated Word: deals
# Attribution: 0.7987385044165377
# ====================================================
# Total Desired Attribution: 0.7987385044165377
# Total Attribution Score: 1.7043163151994132
# Test Case Score: 0.4686562566427591
#
# Processing index 9563 with text: A man and a woman walk at a flea market.The couple are shopping for deals.
# Annotated Word: couple
# Attribution: 0.27845001358111354
# ====================================================
# Total Desired Attribution: 0.27845001358111354
# Total Attribution Score: 1.7993396521804144
# Test Case Score: 0.15475122400803637
#
# Processing index 9564 with text: A group of people, including one man carrying a silver tripod, stand in front of a large building featuring numerous columns.Gerbils chat on Gruveo.
# Annotated Word: stand
# Attribution: 0.18878512603663739
# ====================================================
# Annotated Word: in
# Attribution: 0.09008874267045545
# ====================================================
# Annotated Word: front
# Attribution: 0.0918634455951393
# ====================================================
# Annotated Word: of
# Attribution: 0.024766051017398625
# ====================================================
# Annotated Word: a
# Attribution: 0.06890300874688789
# ====================================================
# Annotated Word: large
# Attribution: 0.055437617598235664
# ====================================================
# Annotated Word: building
# Attribution: 0.137145690366314
# ====================================================
# Annotated Word: ge
# Attribution: 0.1663141727037726
# ====================================================
# Annotated Word: ##rb
# Attribution: 0.16197701258095082
# ====================================================
# Annotated Word: ##ils
# Attribution: 0.3861567720084339
# ====================================================
# Total Desired Attribution: 1.3714376393242258
# Total Attribution Score: 3.5334400337524303
# Test Case Score: 0.3881310072404968
#
# Processing index 9565 with text: A group of people, including one man carrying a silver tripod, stand in front of a large building featuring numerous columns.People are standing.
# Annotated Word: group
# Attribution: -0.0485357562955361
# ====================================================
# Annotated Word: of
# Attribution: -0.004354235267538136
# ====================================================
# Annotated Word: people
# Attribution: -0.10402062334571383
# ====================================================
# Annotated Word: ,
# Attribution: 0.06998443560423236
# ====================================================
# Annotated Word: front
# Attribution: 0.0024637877723060557
# ====================================================
# Annotated Word: of
# Attribution: 0.061120442548661294
# ====================================================
# Annotated Word: a
# Attribution: 0.0933708243830175
# ====================================================
# Annotated Word: large
# Attribution: 0.09514193592662065
# ====================================================
# Annotated Word: people
# Attribution: 0.011838540004937665
# ====================================================
# Annotated Word: standing
# Attribution: 0.6136296230686914
# ====================================================
# Annotated Word: .
# Attribution: -0.03047941787354417
# ====================================================
# Total Desired Attribution: 0.7601595565261348
# Total Attribution Score: 2.6535553129717857
# Test Case Score: 0.28646832904146713
#
# Processing index 9566 with text: A group of people, including one man carrying a silver tripod, stand in front of a large building featuring numerous columns.The building is historical.
# Annotated Word: historical
# Attribution: -0.8819305679375321
# ====================================================
# Annotated Word: .
# Attribution: 0.10297018693940081
# ====================================================
# Total Desired Attribution: -0.7789603809981313
# Total Attribution Score: 1.369108419341173
# Test Case Score: -0.568954488916936
#
# Processing index 9567 with text: Eight tourists stand at a railing looking at an attraction.The tourists stood at the railing looking down at the city
# Annotated Word: city
# Attribution: 0.42621974139584423
# ====================================================
# Total Desired Attribution: 0.42621974139584423
# Total Attribution Score: 2.363659397510571
# Test Case Score: 0.1803219794885604
#
# Processing index 9568 with text: Eight tourists stand at a railing looking at an attraction.The tourists were on a bus tour
#
# Processing index 9569 with text: Eight tourists stand at a railing looking at an attraction.The attraction drew the attention of the tourists
#
# Processing index 9570 with text: A group walking in the middle of a walkway with a green divider, and a woman is walking by herself off to the right.The group is eating lunch at a small cafe.
# Annotated Word: walking
# Attribution: -0.10652900815519808
# ====================================================
# Annotated Word: walkway
# Attribution: 0.05803638939683817
# ====================================================
# Annotated Word: eating
# Attribution: 0.5046510095191706
# ====================================================
# Annotated Word: lunch
# Attribution: 0.2875643769324211
# ====================================================
# Annotated Word: cafe
# Attribution: 0.20425699578819673
# ====================================================
# Annotated Word: .
# Attribution: -0.11257755726535941
# ====================================================
# Total Desired Attribution: 0.8354022062160692
# Total Attribution Score: 3.526954773990125
# Test Case Score: 0.23686218274666435
#
# Processing index 9571 with text: A group walking in the middle of a walkway with a green divider, and a woman is walking by herself off to the right.The group is taking a tour.
# Annotated Word: tour
# Attribution: 0.4644124132989075
# ====================================================
# Annotated Word: .
# Attribution: -0.03402764991482432
# ====================================================
# Total Desired Attribution: 0.43038476338408316
# Total Attribution Score: 2.085560352072758
# Test Case Score: 0.20636408961090016
#
# Processing index 9572 with text: A group walking in the middle of a walkway with a green divider, and a woman is walking by herself off to the right.The woman is walking away from the group.
# Annotated Word: group
# Attribution: -0.095523050867273
# ====================================================
# Annotated Word: woman
# Attribution: -0.20995576370732555
# ====================================================
# Annotated Word: walking
# Attribution: 0.4012599657400474
# ====================================================
# Annotated Word: by
# Attribution: 0.03851029885611314
# ====================================================
# Annotated Word: herself
# Attribution: 0.09450368486691883
# ====================================================
# Annotated Word: woman
# Attribution: -0.44267617059692377
# ====================================================
# Annotated Word: walking
# Attribution: 0.41113478263903686
# ====================================================
# Annotated Word: away
# Attribution: -0.34755749994210344
# ====================================================
# Annotated Word: from
# Attribution: -0.013734999869914642
# ====================================================
# Annotated Word: the
# Attribution: 0.07432730357232621
# ====================================================
# Annotated Word: group
# Attribution: 0.019161973338678667
# ====================================================
# Annotated Word: .
# Attribution: 0.005452313725389031
# ====================================================
# Total Desired Attribution: -0.06509716224503029
# Total Attribution Score: 2.1660901468871216
# Test Case Score: -0.03005284075484168
#
# Processing index 9573 with text: Man balding with a mustache and semi beard standing wearing a psychedelic button shirt playing the guitar as he sings.The man has no vocal cords.
# Annotated Word: sings
# Attribution: -0.08653451045740619
# ====================================================
# Annotated Word: .
# Attribution: -0.16188865179080533
# ====================================================
# Annotated Word: has
# Attribution: -0.01669553308042627
# ====================================================
# Annotated Word: no
# Attribution: 0.9327411402372559
# ====================================================
# Annotated Word: vocal
# Attribution: 0.04507034097852351
# ====================================================
# Annotated Word: cords
# Attribution: 0.0686370663937263
# ====================================================
# Annotated Word: .
# Attribution: -0.054457697927061226
# ====================================================
# Total Desired Attribution: 0.7268721543538066
# Total Attribution Score: 1.8425493848669316
# Test Case Score: 0.3944926308752919
#
# Processing index 9574 with text: Man balding with a mustache and semi beard standing wearing a psychedelic button shirt playing the guitar as he sings.The man loves to play music for people.
# Annotated Word: loves
# Attribution: 0.046270369816243134
# ====================================================
# Annotated Word: to
# Attribution: -0.11978037186255178
# ====================================================
# Annotated Word: play
# Attribution: 0.27836074555780527
# ====================================================
# Annotated Word: music
# Attribution: -0.010393441648792884
# ====================================================
# Annotated Word: for
# Attribution: 0.111800651222116
# ====================================================
# Annotated Word: people
# Attribution: -0.09289109189944751
# ====================================================
# Annotated Word: .
# Attribution: -0.053720084093874576
# ====================================================
# Total Desired Attribution: 0.15964677709149766
# Total Attribution Score: 2.3511478820729605
# Test Case Score: 0.06790163150041428
#
# Processing index 9575 with text: Man balding with a mustache and semi beard standing wearing a psychedelic button shirt playing the guitar as he sings.The man knows how to play the guitar.
# Annotated Word: man
# Attribution: -0.042352587930010475
# ====================================================
# Annotated Word: playing
# Attribution: 0.23322646674096018
# ====================================================
# Annotated Word: the
# Attribution: 0.028156836944720216
# ====================================================
# Annotated Word: guitar
# Attribution: 0.33469117142118787
# ====================================================
# Annotated Word: man
# Attribution: -0.07524493171795468
# ====================================================
# Annotated Word: knows
# Attribution: 0.3872625782890127
# ====================================================
# Annotated Word: how
# Attribution: -0.17654559880226622
# ====================================================
# Annotated Word: to
# Attribution: 0.09386191380852589
# ====================================================
# Annotated Word: play
# Attribution: -0.03376668976329272
# ====================================================
# Total Desired Attribution: 0.749289158990883
# Total Attribution Score: 2.299855367360913
# Test Case Score: 0.32579838263946714
#
# Processing index 9576 with text: Little boy peering into a glass display case.a boy looks in a case
# Annotated Word: little
# Attribution: -0.10807984374209206
# ====================================================
# Annotated Word: boy
# Attribution: 0.6251682647054754
# ====================================================
# Annotated Word: glass
# Attribution: 0.0347393696586939
# ====================================================
# Annotated Word: display
# Attribution: 0.05833644529225249
# ====================================================
# Annotated Word: case
# Attribution: -0.036616174923791704
# ====================================================
# Annotated Word: .
# Attribution: -0.0029286064060925795
# ====================================================
# Annotated Word: boy
# Attribution: 0.3709813702068417
# ====================================================
# Annotated Word: case
# Attribution: 0.5555736835373053
# ====================================================
# Total Desired Attribution: 1.4971745083285923
# Total Attribution Score: 2.5374742298576205
# Test Case Score: 0.5900255028058353
#
# Processing index 9577 with text: Little boy peering into a glass display case.A trophy is in the case
#
# Processing index 9578 with text: Little boy peering into a glass display case.a girl is walking
# Annotated Word: boy
# Attribution: 0.10465797439186043
# ====================================================
# Annotated Word: girl
# Attribution: 0.13600705177283967
# ====================================================
# Total Desired Attribution: 0.2406650261647001
# Total Attribution Score: 1.590118950567053
# Test Case Score: 0.1513503289039329
#
# Processing index 9579 with text: A man walks into a transportation station and two officers in neon jackets stand guard.This is a transportation station
# Annotated Word: transportation
# Attribution: 0.5243283099477709
# ====================================================
# Annotated Word: station
# Attribution: 0.034107076954306176
# ====================================================
# Annotated Word: transportation
# Attribution: 0.626743978299089
# ====================================================
# Annotated Word: station
# Attribution: 0.37330695040303036
# ====================================================
# Total Desired Attribution: 1.5584863156041964
# Total Attribution Score: 2.2794846599924656
# Test Case Score: 0.6837011641084471
#
# Processing index 9580 with text: A man walks into a transportation station and two officers in neon jackets stand guard.The man is at a school
# Annotated Word: walks
# Attribution: -0.06429950140664448
# ====================================================
# Annotated Word: into
# Attribution: 0.01120139210839781
# ====================================================
# Annotated Word: a
# Attribution: -0.10146514645725875
# ====================================================
# Annotated Word: transportation
# Attribution: 0.3665412822748588
# ====================================================
# Annotated Word: station
# Attribution: 0.05571773309790999
# ====================================================
# Annotated Word: at
# Attribution: -0.06742352829848154
# ====================================================
# Annotated Word: a
# Attribution: -0.04381171133826231
# ====================================================
# Annotated Word: school
# Attribution: 0.806567232035932
# ====================================================
# Total Desired Attribution: 0.9630277520164515
# Total Attribution Score: 2.0843696995691268
# Test Case Score: 0.4620234847088427
#
# Processing index 9581 with text: A man walks into a transportation station and two officers in neon jackets stand guard.The guards are watching a suspicious man
# Annotated Word: guards
# Attribution: 0.04539085988201593
# ====================================================
# Annotated Word: watching
# Attribution: -0.7576660167425799
# ====================================================
# Annotated Word: suspicious
# Attribution: 0.4058549729238263
# ====================================================
# Annotated Word: man
# Attribution: 0.15327657024119862
# ====================================================
# Total Desired Attribution: -0.15314361369553908
# Total Attribution Score: 1.5150199944272438
# Test Case Score: -0.10108355946380451
#
# Processing index 9582 with text: Children play in the sand surrounded by a sand structure with a lot of window like openings.The children are playing in an amusement park.
#
# Processing index 9583 with text: Children play in the sand surrounded by a sand structure with a lot of window like openings.The children are playing in the sand.
# Annotated Word: children
# Attribution: 0.6233177680416051
# ====================================================
# Annotated Word: play
# Attribution: 0.030319469834799644
# ====================================================
# Annotated Word: in
# Attribution: 0.037351824929027284
# ====================================================
# Annotated Word: the
# Attribution: -0.011944520122109082
# ====================================================
# Annotated Word: sand
# Attribution: -0.07059201081945193
# ====================================================
# Annotated Word: children
# Attribution: 0.5563361912137564
# ====================================================
# Annotated Word: playing
# Attribution: 0.08432198714271309
# ====================================================
# Annotated Word: in
# Attribution: -0.05947129462050308
# ====================================================
# Annotated Word: the
# Attribution: 0.30561690533970753
# ====================================================
# Annotated Word: sand
# Attribution: 0.11710540561268562
# ====================================================
# Annotated Word: .
# Attribution: 0.20384167188473576
# ====================================================
# Total Desired Attribution: 1.816203398436966
# Total Attribution Score: 2.5585010141065645
# Test Case Score: 0.7098701108278392
#
# Processing index 9584 with text: Children play in the sand surrounded by a sand structure with a lot of window like openings.The children playing in the sand all know each other.
# Annotated Word: all
# Attribution: -0.07785119723626074
# ====================================================
# Annotated Word: know
# Attribution: 0.9393289241440553
# ====================================================
# Annotated Word: each
# Attribution: 0.02489621692360901
# ====================================================
# Annotated Word: other
# Attribution: -0.03258703894905614
# ====================================================
# Annotated Word: .
# Attribution: -0.13694460065960776
# ====================================================
# Total Desired Attribution: 0.7168423042227396
# Total Attribution Score: 1.4695662299347003
# Test Case Score: 0.4877917644137701
#
# Processing index 9585 with text: Four small children playing in the courtyard of a large building made out of clay or sand.Four children who live in a large building are in the courtyard playing.
# Annotated Word: live
# Attribution: -0.1708884494256797
# ====================================================
# Total Desired Attribution: -0.1708884494256797
# Total Attribution Score: 1.903518931023517
# Test Case Score: -0.08977501964416684
#
# Processing index 9586 with text: Four small children playing in the courtyard of a large building made out of clay or sand.Four children are outdoors playing.
# Annotated Word: small
# Attribution: -0.030250916190145433
# ====================================================
# Annotated Word: playing
# Attribution: 0.03313134818825816
# ====================================================
# Annotated Word: courtyard
# Attribution: 0.04681379520324849
# ====================================================
# Annotated Word: children
# Attribution: 0.36684219026713366
# ====================================================
# Annotated Word: outdoors
# Attribution: 0.8114530242986187
# ====================================================
# Total Desired Attribution: 1.2279894417671136
# Total Attribution Score: 2.1990984077552667
# Test Case Score: 0.5584058618916403
#
# Processing index 9587 with text: Four small children playing in the courtyard of a large building made out of clay or sand.For small children are playing in the sand on a deserted beach.
#
# Processing index 9588 with text: A black and brown dog is jumping on blocks of concrete in the water.The dog is jumping.
# Annotated Word: black
# Attribution: 0.001554983772001461
# ====================================================
# Annotated Word: and
# Attribution: -0.009228431000330965
# ====================================================
# Annotated Word: brown
# Attribution: 0.044262373567720587
# ====================================================
# Annotated Word: dog
# Attribution: 0.08771481348081377
# ====================================================
# Annotated Word: dog
# Attribution: 0.14250634876192242
# ====================================================
# Total Desired Attribution: 0.2668100885821273
# Total Attribution Score: 2.1315583708791843
# Test Case Score: 0.1251713733141066
#
# Processing index 9589 with text: A black and brown dog is jumping on blocks of concrete in the water.The dog wants to play.
# Annotated Word: play
# Attribution: -0.6367175524718672
# ====================================================
# Annotated Word: .
# Attribution: -0.14402498368705774
# ====================================================
# Total Desired Attribution: -0.780742536158925
# Total Attribution Score: 1.8031122669719784
# Test Case Score: -0.43299718517807534
#
# Processing index 9590 with text: A black and brown dog is jumping on blocks of concrete in the water.The dog is sleeping.
# Annotated Word: jumping
# Attribution: 0.3446675496584859
# ====================================================
# Annotated Word: sleeping
# Attribution: 0.9166636715654856
# ====================================================
# Annotated Word: .
# Attribution: -0.01174520858236422
# ====================================================
# Total Desired Attribution: 1.2495860126416072
# Total Attribution Score: 1.5369323147348126
# Test Case Score: 0.8130390653261883
#
# Processing index 9591 with text: A man squatting in a park looking at something in the distance.A man is watching his son playing on the swingset.
#
# Processing index 9592 with text: A man squatting in a park looking at something in the distance.A man is swimming in the ocean.
# Annotated Word: squat
# Attribution: -0.028940468092532232
# ====================================================
# Annotated Word: ##ting
# Attribution: 0.019225876375754427
# ====================================================
# Annotated Word: swimming
# Attribution: 0.600995391283636
# ====================================================
# Total Desired Attribution: 0.5912807995668582
# Total Attribution Score: 2.620790627639833
# Test Case Score: 0.2256116125153192
#
# Processing index 9593 with text: A man squatting in a park looking at something in the distance.A man sees something while in a park.
# Annotated Word: man
# Attribution: 0.2072686920634931
# ====================================================
# Annotated Word: squat
# Attribution: 0.0975178571862331
# ====================================================
# Annotated Word: ##ting
# Attribution: -0.10033490996404769
# ====================================================
# Annotated Word: looking
# Attribution: -0.11951505484057669
# ====================================================
# Annotated Word: man
# Attribution: 0.3257357417978547
# ====================================================
# Annotated Word: sees
# Attribution: 0.15233800811122492
# ====================================================
# Total Desired Attribution: 0.5630103343541815
# Total Attribution Score: 3.007039113838177
# Test Case Score: 0.1872307984832151
#
# Processing index 9594 with text: A snowboarder with a maroon coat sails through the air.The snowboarder has never tried this jump before.
# Annotated Word: has
# Attribution: 0.1734300319044529
# ====================================================
# Annotated Word: never
# Attribution: -0.18831522924604596
# ====================================================
# Annotated Word: tried
# Attribution: -0.18625391882319356
# ====================================================
# Annotated Word: this
# Attribution: -0.33771459692085737
# ====================================================
# Annotated Word: jump
# Attribution: 0.5934434797807345
# ====================================================
# Annotated Word: before
# Attribution: 0.3505123793163997
# ====================================================
# Annotated Word: .
# Attribution: 0.2678909480557638
# ====================================================
# Total Desired Attribution: 0.672993094067254
# Total Attribution Score: 2.4937532937185867
# Test Case Score: 0.2698715609769534
#
# Processing index 9595 with text: A snowboarder with a maroon coat sails through the air.A person is snowboarding.
# Annotated Word: snow
# Attribution: 0.6302277319913072
# ====================================================
# Annotated Word: ##board
# Attribution: 0.10914079619106123
# ====================================================
# Annotated Word: ##er
# Attribution: -0.095620891740223
# ====================================================
# Annotated Word: sails
# Attribution: 0.06065687868470966
# ====================================================
# Annotated Word: person
# Attribution: 0.5622110514084524
# ====================================================
# Annotated Word: snow
# Attribution: 0.11281827815509471
# ====================================================
# Annotated Word: ##boarding
# Attribution: 0.1383714793803819
# ====================================================
# Annotated Word: .
# Attribution: 0.29228034310954387
# ====================================================
# Total Desired Attribution: 1.8100856671803278
# Total Attribution Score: 2.2307270449976846
# Test Case Score: 0.811433057773416
#
# Processing index 9596 with text: A snowboarder with a maroon coat sails through the air.The snowboarder is naked.
# Annotated Word: maroon
# Attribution: -0.001395602696875171
# ====================================================
# Annotated Word: coat
# Attribution: -0.02410712663334162
# ====================================================
# Annotated Word: naked
# Attribution: 0.9613778444430833
# ====================================================
# Annotated Word: .
# Attribution: 0.12777694629335293
# ====================================================
# Total Desired Attribution: 1.0636520614062195
# Total Attribution Score: 1.5378138000439288
# Test Case Score: 0.6916650516309812
#
# Processing index 9597 with text: A man is in front of a dryer in a laundromat with both hands reaching into a bin or basket.A woman reaches into a basket at a store
# Annotated Word: man
# Attribution: 0.46299289585289144
# ====================================================
# Annotated Word: woman
# Attribution: 0.8229952692045325
# ...
# ====================================================
# Annotated Word: pushing
# Attribution: -0.15489370777830105
# ====================================================
# Total Desired Attribution: -0.053248225375330596
# Total Attribution Score: 2.1003012378959585
# Test Case Score: -0.0253526610443146
#
# Processing index 9808 with text: Two gondola operators sit along a road in Italy.The gondola operators are in uniform.
# Annotated Word: uniform
# Attribution: 0.22035009070174072
# ====================================================
# Annotated Word: .
# Attribution: -0.18921712014133574
# ====================================================
# Total Desired Attribution: 0.031132970560404982
# Total Attribution Score: 2.622115395996178
# Test Case Score: 0.011873226711510587
#
# Processing index 9809 with text: A boy drags his sled through the snow.a boy drags a sled up the hill
# Annotated Word: sl
# Attribution: -0.07104349950739042
# ====================================================
# Annotated Word: ##ed
# Attribution: -0.08427391742741479
# ====================================================
# Annotated Word: up
# Attribution: -0.13470942078048145
# ====================================================
# Annotated Word: the
# Attribution: -0.3207375378773853
# ====================================================
# Annotated Word: hill
# Attribution: 0.7166910336213669
# ====================================================
# Total Desired Attribution: 0.10592665802869494
# Total Attribution Score: 2.184761557076288
# Test Case Score: 0.048484310649647776
#
# Processing index 9810 with text: A boy drags his sled through the snow.a boy drags his dog
#
# Processing index 9811 with text: A boy drags his sled through the snow.a boy drags a sled
# Annotated Word: a
# Attribution: 0.001389698106895216
# ====================================================
# Annotated Word: boy
# Attribution: 0.6456501062239783
# ====================================================
# Annotated Word: drag
# Attribution: -0.07224508786799282
# ====================================================
# Annotated Word: ##s
# Attribution: -0.06189506579525543
# ====================================================
# Annotated Word: his
# Attribution: 0.27452120802829566
# ====================================================
# Annotated Word: sl
# Attribution: -0.024069795515292435
# ====================================================
# Annotated Word: ##ed
# Attribution: -0.025191565449856283
# ====================================================
# Annotated Word: through
# Attribution: -0.0018609382563028157
# ====================================================
# Annotated Word: the
# Attribution: -0.188196356067002
# ====================================================
# Annotated Word: snow
# Attribution: 0.15979653940670113
# ====================================================
# Annotated Word: .
# Attribution: 0.11455199444840024
# ====================================================
# Annotated Word: a
# Attribution: 0.040395988607278215
# ====================================================
# Annotated Word: boy
# Attribution: 0.5277801560694235
# ====================================================
# Annotated Word: drag
# Attribution: -0.18297755247570904
# ====================================================
# Annotated Word: ##s
# Attribution: 0.1444682850137495
# ====================================================
# Annotated Word: sl
# Attribution: -0.015429601543554501
# ====================================================
# Annotated Word: ##ed
# Attribution: 0.2977033233085942
# ====================================================
# Total Desired Attribution: 1.6343913362423508
# Total Attribution Score: 2.2115890998133207
# Test Case Score: 0.7390122045638174
#
# Processing index 9812 with text: A man wearing glasses and a ragged costume is playing a Jaguar electric guitar and singing with the accompaniment of a drummer.Two men are playing on a street corner.
#
# Processing index 9813 with text: A man wearing glasses and a ragged costume is playing a Jaguar electric guitar and singing with the accompaniment of a drummer.Two men are playing frisbee in the park.
# Annotated Word: a
# Attribution: 0.09076416535215572
# ====================================================
# Annotated Word: man
# Attribution: 0.147079783631717
# ====================================================
# Annotated Word: playing
# Attribution: -0.01853314632828493
# ====================================================
# Annotated Word: electric
# Attribution: 0.11572033589888894
# ====================================================
# Annotated Word: guitar
# Attribution: 0.10341346139845403
# ====================================================
# Annotated Word: two
# Attribution: -0.08410010073821642
# ====================================================
# Annotated Word: men
# Attribution: 0.43370675468428965
# ====================================================
# Annotated Word: playing
# Attribution: 0.22847665785664642
# ====================================================
# Annotated Word: fr
# Attribution: 0.42661523702531967
# ====================================================
# Annotated Word: ##is
# Attribution: 0.22142844520652555
# ====================================================
# Annotated Word: ##bee
# Attribution: 0.21158730555858096
# ====================================================
# Total Desired Attribution: 1.876158899546077
# Total Attribution Score: 3.686927846212088
# Test Case Score: 0.5088678102213536
#
# Processing index 9814 with text: A man wearing glasses and a ragged costume is playing a Jaguar electric guitar and singing with the accompaniment of a drummer.A man with glasses and a disheveled outfit is playing a guitar and singing along with a drummer.
# Annotated Word: ragged
# Attribution: -0.026543083873253003
# ====================================================
# Annotated Word: dish
# Attribution: -0.24103503047235963
# ====================================================
# Annotated Word: ##eve
# Attribution: 0.08989913916903668
# ====================================================
# Annotated Word: ##led
# Attribution: 0.05641554043790776
# ====================================================
# Total Desired Attribution: -0.12126343473866819
# Total Attribution Score: 2.383397857106765
# Test Case Score: -0.05087838540136614
#
# Processing index 9815 with text: A female dancer wearing all white dancing while a photographer wearing all white takes her picture.A girl dancing and photographer take a photo
# Annotated Word: dancing
# Attribution: 0.0012082352404367033
# ====================================================
# Annotated Word: takes
# Attribution: 0.014996383983298079
# ====================================================
# Annotated Word: her
# Attribution: 0.17334726123464334
# ====================================================
# Annotated Word: picture
# Attribution: 0.052543984498021085
# ====================================================
# Annotated Word: .
# Attribution: -0.2909172184105708
# ====================================================
# Annotated Word: dancing
# Attribution: 0.057911943265698256
# ====================================================
# Annotated Word: take
# Attribution: 0.045320883024959575
# ====================================================
# Annotated Word: a
# Attribution: 0.3124717332308376
# ====================================================
# Annotated Word: photo
# Attribution: 0.17487960501047292
# ====================================================
# Total Desired Attribution: 0.5417628110777968
# Total Attribution Score: 2.566660602039597
# Test Case Score: 0.21107691864178885
#
# Processing index 9816 with text: A female dancer wearing all white dancing while a photographer wearing all white takes her picture.Some players are playing cricket in ground
# Annotated Word: female
# Attribution: -0.00764438326589107
# ====================================================
# Annotated Word: dancer
# Attribution: -0.012331827201650733
# ====================================================
# Annotated Word: cricket
# Attribution: 0.6430488395087232
# ====================================================
# Total Desired Attribution: 0.6230726290411813
# Total Attribution Score: 3.323586588490069
# Test Case Score: 0.18746995525825855
#
# Processing index 9817 with text: A female dancer wearing all white dancing while a photographer wearing all white takes her picture.A girl is dancing and anothe man take a photo
#
# Processing index 9818 with text: Two women are observing something together.Two women are looking at a flower together.
# Annotated Word: a
# Attribution: -0.4509838822300527
# ====================================================
# Annotated Word: flower
# Attribution: 0.20054906917660392
# ====================================================
# Total Desired Attribution: -0.2504348130534488
# Total Attribution Score: 1.726540679055732
# Test Case Score: -0.1450500507120486
#
# Processing index 9819 with text: Two women are observing something together.Two women are standing with their eyes closed.
# Annotated Word: observing
# Attribution: -0.5285733781376272
# ====================================================
# Annotated Word: eyes
# Attribution: 0.10383500689668108
# ====================================================
# Annotated Word: closed
# Attribution: 0.1411719118874266
# ====================================================
# Annotated Word: .
# Attribution: 0.03307104289380678
# ====================================================
# Total Desired Attribution: -0.25049541645971274
# Total Attribution Score: 2.6336082515141563
# Test Case Score: -0.09511491176248171
#
# Processing index 9820 with text: Two women are observing something together.Two girls are looking at something.
# Annotated Word: observing
# Attribution: 0.3555847418714455
# ====================================================
# Annotated Word: looking
# Attribution: 0.46611741980529436
# ====================================================
# Total Desired Attribution: 0.8217021616767399
# Total Attribution Score: 2.0373193282005255
# Test Case Score: 0.4033251686678461
#
# Processing index 9821 with text: A man in a black leather jacket and a book in his hand speaks in a classroom.A man is flying a kite.
# Annotated Word: speaks
# Attribution: -0.012216769503382867
# ====================================================
# Annotated Word: in
# Attribution: 0.023043087640762638
# ====================================================
# Annotated Word: a
# Attribution: 0.02706462591285557
# ====================================================
# Annotated Word: classroom
# Attribution: -0.021380228464751853
# ====================================================
# Annotated Word: .
# Attribution: 0.020941548915504413
# ====================================================
# Annotated Word: flying
# Attribution: 0.39430852217349
# ====================================================
# Annotated Word: a
# Attribution: -0.3733974107438971
# ====================================================
# Annotated Word: kite
# Attribution: 0.8199129361304419
# ====================================================
# Annotated Word: .
# Attribution: -0.08561877307817663
# ====================================================
# Total Desired Attribution: 0.7926575389828461
# Total Attribution Score: 1.5134167667855976
# Test Case Score: 0.5237536390365233
#
# Processing index 9822 with text: A man in a black leather jacket and a book in his hand speaks in a classroom.A man is speaking in a classroom.
# Annotated Word: speaks
# Attribution: 0.36852405504247343
# ====================================================
# Annotated Word: speaking
# Attribution: 0.37748326061520143
# ====================================================
# Total Desired Attribution: 0.7460073156576749
# Total Attribution Score: 2.4679045281033574
# Test Case Score: 0.3022837014813531
#
# Processing index 9823 with text: A man in a black leather jacket and a book in his hand speaks in a classroom.A man is teaching science in a classroom.
# Annotated Word: science
# Attribution: 0.1858974556244925
# ====================================================
# Total Desired Attribution: 0.1858974556244925
# Total Attribution Score: 2.3586198333093513
# Test Case Score: 0.07881620132213592
#
# Final Attribution results: [0.5794930689518754, 0.4625751730847628, 0.778592696916674, -0.15965410707277955, 0.2788146494988614, 0.24935176821057972, -0.14752299761276091, 0.07340054943659159, 0.170148457717884, 0.18338421512415526, 0.308643063063992, 0.030798515666029903, -0.008937216160690282, -0.051715346081109476, 0.21255518542546983, 0.3015662946937994, 0.3537898787125188, -0.2754043698618448, 0.21328187059968265, -0.20692754390600682, 0.6706619740662669, -0.037120380088600496, 0.09416039352174206, 0.34068661242867887, 0.27878089135468803, 0.5194479375205086, 0.17889653093917612, -0.018277755366306127, 0.22409721722270745, -0.03941015335498656, -0.14363988963917715, 0.664779703397679, 0.5501537950343551, 0.3930630608437186, 0.5251609835113147, 0.030813160196505172, -0.025923625978526908, 0.2091608549113564, -0.15623574333326998, 0.6787351410358562, 0.016169562736533503, -0.3430140131492351, 0.15253013913739105, -0.5041944002595644, 0.28630433771943065, 0.21209486108240147, 0.2488017317909686, 0.4968600443313526, 0.2350411824927592, 0.4105136575197458, 0.33634141572224724, 0.48482140904250765, 0.3888854610387306, 0.33051440777118474, 0.5076901229059219, 0.7586749524842309, 0.17760093662039825, 0.5210890727263393, 0.1367836874881743, 0.27794119303128473, 0.5211306596898297, 0.040241889946792536, 0.463871541803982, 0.03819300745707132, 0.32340798381743907, 0.1550189719821791, -0.028512851448291982, 0.4060379345958544, 0.02667812781103868, 0.08157730489901016, 0.7531971000923837, 0.19639531574690863, 0.27378327943742004, 0.3341935481508263, 0.6433673750733597, 0.6948054808744847, -0.034679170485552975, 0.7568709705801547, 0.7693591236914974, 0.18451636132533614, 0.6648479252537112, 0.5686867402267082, 0.1440193313650778, 0.8203037942179998, 0.28776024794647764, 0.5412360994054038, -0.03349274065239199, 0.2073095749484064, 0.2667440675480438, 0.13675122569294598, -0.1490748270516816, 0.2133061620075595, 0.457617627036195, 0.639028556636734, 0.8463381201336986, 0.002403337409465978, 0.17314377999709182, 0.2556305175983631, 0.35729749138206496, 0.12226232710312102, 0.4195413476542664, -0.20698777392356404, 0.5218258258348984, 0.047707594531012844, -0.09068511244212041, 0.5751370803782944, 0.5946529765748817, 0.5813291524235082, 0.16877249668440894, 0.2041800916408689, 0.3360600574385328, -0.12861939951375728, -0.07679428596023839, 0.46127138334813617, 0.20732768741181437, -0.19452278104168536, 0.021815909738609647, 0.6962182818724707, 0.36245118187237024, 0.9033993993196774, 0.21589763458749905, 0.11959288182611756, 0.3703161350713497, 0.12057787545690765, -0.010242967272552651, 0.2166092098152068, 0.14352214101444932, -0.04007151262808158, 0.020627787636690934, 0.5077907858366274, -0.5314829789085647, 0.2107916873749143, 0.9703341343115538, 0.04306551907405513, -0.02845626226785876, 0.4346571549842719, 0.2970254069095854, 0.00493787722507781, 0.45490737925126695, 0.7077336231649866, 0.6572878508181105, 0.1777957687186642, 0.1823950251397754, 0.2747284686404311, 0.1764392423067306, 0.4575290008578856, 0.143899800612656, 0.33967811797284936, 0.05146792217494647, 0.35149439772085084, 0.2513458631000691, 0.22692768108293682, 0.264473216718262, 0.5921057879283739, 0.19936347209536892, -0.03692523902518523, 0.518765633075494, 0.542994377563344, 0.4887543298986875, 0.8102872186476865, 0.42140480783104567, -0.08128891714914319, 0.2214219664729573, 0.3640115782751884, -0.23647296314228353, -0.11903042427462374, 0.630577026869182, 0.47540640313647065, -0.520197286009641, -0.0991753734928656, 0.17782120251616837, 0.03687341655454842, 0.4979058179732215, 0.17155655755858007, -0.07767138007142123, 0.34857708623991834, 0.23298473257613225, 0.39886530973719536, 0.3308961086300235, -0.08149942306772202, 0.622783512393404, 0.18493362029983385, 0.5314658281480507, 0.10392745716015099, 0.7492295658794624, 0.12680403261948833, 0.6050620778681285, 0.3507079217561391, 0.5171171364045815, 0.2650916732213708, 0.5949456577871631, 0.8411866099637211, 0. ...

# %%
values = results
df = pd.DataFrame(values, columns=['Attribution'])
df.index += 1
df.reset_index(inplace=True)
df.rename(columns={'index': 'Test Case'}, inplace=True)


df.to_csv('attribution2.csv', index=False) # Save to CSV
