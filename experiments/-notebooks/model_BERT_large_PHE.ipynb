# %%
import pandas as pd
import time, datetime, numpy as np
import random

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

from transformers import BertTokenizer, BertForSequenceClassification
from transformers import AdamW, get_linear_schedule_with_warmup
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import AdamW, get_linear_schedule_with_warmup

# %% [markdown]
# ## Mounting Google Drive to Collab

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/CS4248/esnli_train.csv')
test = pd.read_csv('/content/drive/MyDrive/CS4248/esnli_test.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.shape
# Out:
# (259999, 10)

# %%
df.head()
# Out:
#                 pairID     gold_label  \
# 0  3416050480.jpg#4r1n        neutral
# 1  3416050480.jpg#4r1c  contradiction
# 2  3416050480.jpg#4r1e     entailment
# 3  2267923837.jpg#2r1n        neutral
# 4  2267923837.jpg#2r1e     entailment
#
#                                            Sentence1  \
# 0  A person on a horse jumps over a broken down a...
# 1  A person on a horse jumps over a broken down a...
# 2  A person on a horse jumps over a broken down a...
# 3              Children smiling and waving at camera
# 4              Children smiling and waving at camera
#
#                                            Sentence2  \
# 0  A person is training his horse for a competition.
# 1      A person is at a diner, ordering an omelette.
# 2                  A person is outdoors, on a horse.
# 3                  They are smiling at their parents
# 4                         There are children present
#
#                                        Explanation_1        WorkerId  \
# 0   the person is not necessarily training his horse   AF0PI3RISB5Q7
# 1  One cannot be on a jumping horse cannot be a d...  A36ZT2WFIA2HMF
# 2                 a broken down airplane is outdoors  A2GK75ZQTX2RDZ
# 3  Just because they are smiling and waving at a ...  A18TOIDG32QICP
# 4  The children must be present to see them smili...   AEX0YE6TUZRHT
#
#                                   Sentence1_marked_1  \
# 0  A person on a horse jumps over a broken down a...
# 1   A person *on* *a* *horse* *jumps* over a brok...
# 2   A person on a horse jumps over *a* *broken* *...
# 3              Children smiling and waving at camera
# 4      *Children* *smiling* *and* *waving* at camera
#
#                                   Sentence2_marked_1 Sentence1_Highlighted_1  \
# 0   A person is *training* *his* *horse* for a co...                      {}
# 1   A person *is* *at* *a* *diner,* *ordering* an...                 4,2,3,5
# 2                A person is *outdoors,* on a horse.                8,9,10,7
# 3            They are smiling *at* *their* *parents*                      {}
# 4                       There are children *present*                 0,1,3,2
#
#   Sentence2_Highlighted_1
# 0                   3,4,5
# 1               2,5,4,3,6
# 2                       3
# 3                   5,3,4
# 4                       3

# %% [markdown]
# ## Utility Functions

# %%
def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    elapsed_rounded = int(round((elapsed)))
    return str(datetime.timedelta(seconds=elapsed_rounded))

def select_cols(df, col_list):
    '''
    Select columns from a dataframe
    '''
    return df[col_list]

# %% [markdown]
# ## Data Pre-processing Utility Functions

# %%
def combine_sentences(df, col_list):

    # start_token = '[CLS]'
    # seperator = '[SEP]'

    # combined_text_list = [f'{start_token}{s1}{seperator}{s2}' for s1, s2 in zip(sentence1, sentence2)]
    # return combined_text_list

    results_df = df.copy()

    results_df['combined_text'] = '[CLS]' + results_df[col_list].astype(str).agg('[SEP]'.join, axis=1)

    return results_df

# %% [markdown]
# Train/Test Input Data Handling

# %%
# target_cols = ['Sentence1', 'Sentence2', 'gold_label'] # Premise, Hypothesis
target_cols = ['Sentence1', 'Sentence2', 'Explanation_1', 'gold_label'] # Premise, Hypothesis, Explanation
# target_cols = ['Sentence2', 'Sentence1', 'gold_label'] # Hypothesis, Premise
# target_cols = ['Sentence1', 'Explanation_1', 'Sentence2', 'gold_label'] # Premise, Explanation, Hypothesis

df = select_cols(df, target_cols)
test_df = select_cols(test, target_cols)

df.head()
# Out:
#                                            Sentence1  \
# 0  A person on a horse jumps over a broken down a...
# 1  A person on a horse jumps over a broken down a...
# 2  A person on a horse jumps over a broken down a...
# 3              Children smiling and waving at camera
# 4              Children smiling and waving at camera
#
#                                            Sentence2  \
# 0  A person is training his horse for a competition.
# 1      A person is at a diner, ordering an omelette.
# 2                  A person is outdoors, on a horse.
# 3                  They are smiling at their parents
# 4                         There are children present
#
#                                        Explanation_1     gold_label
# 0   the person is not necessarily training his horse        neutral
# 1  One cannot be on a jumping horse cannot be a d...  contradiction
# 2                 a broken down airplane is outdoors     entailment
# 3  Just because they are smiling and waving at a ...        neutral
# 4  The children must be present to see them smili...     entailment

# %%
df = combine_sentences(df, target_cols[:-1])
test_df = combine_sentences(test_df, target_cols[:-1])

df.head()

lables = {
    'entailment': 0,
    'neutral': 1,
    'contradiction': 2
}

df['labels'] = df['gold_label'].map(lables)
test_df['labels'] = test_df['gold_label'].map(lables)

# %%
df.head()
# Out:
#                                            Sentence1  \
# 0  A person on a horse jumps over a broken down a...
# 1  A person on a horse jumps over a broken down a...
# 2  A person on a horse jumps over a broken down a...
# 3              Children smiling and waving at camera
# 4              Children smiling and waving at camera
#
#                                            Sentence2  \
# 0  A person is training his horse for a competition.
# 1      A person is at a diner, ordering an omelette.
# 2                  A person is outdoors, on a horse.
# 3                  They are smiling at their parents
# 4                         There are children present
#
#                                        Explanation_1     gold_label  \
# 0   the person is not necessarily training his horse        neutral
# 1  One cannot be on a jumping horse cannot be a d...  contradiction
# 2                 a broken down airplane is outdoors     entailment
# 3  Just because they are smiling and waving at a ...        neutral
# 4  The children must be present to see them smili...     entailment
#
#                                        combined_text  labels
# 0  [CLS]A person on a horse jumps over a broken d...       1
# 1  [CLS]A person on a horse jumps over a broken d...       2
# 2  [CLS]A person on a horse jumps over a broken d...       0
# 3  [CLS]Children smiling and waving at camera[SEP...       1
# 4  [CLS]Children smiling and waving at camera[SEP...       0

# %%
df['combined_text'][0]
# Out:
# '[CLS]A person on a horse jumps over a broken down airplane.[SEP]A person is training his horse for a competition.[SEP]the person is not necessarily training his horse'

# %%
X = df['combined_text']
y = df['labels']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((233999,), (26000,), (233999,), (26000,))

# %%
X_test = test_df['combined_text']
y_test = test_df['labels']

X_test.shape, y_test.shape
# Out:
# ((9824,), (9824,))

# %%
class NliDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased')

# tokenize train/validation data
train_encodings = tokenizer(X_train.tolist(), truncation=True, padding=True)
val_encodings = tokenizer(X_val.tolist(), truncation=True, padding=True)

# tokenize test data
test_encodings = tokenizer(X_test.tolist(), truncation=True, padding=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]

# %%
# creating Dataset objects
train_dataset = NliDataset(train_encodings, y_train.tolist())
val_dataset = NliDataset(val_encodings, y_val.tolist())
test_dataset = NliDataset(test_encodings, y_test.tolist())

# Create DataLoader instances
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
validation_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
model = BertForSequenceClassification.from_pretrained(
    "bert-large-uncased",
    num_labels = 3,
    output_attentions = False,
    output_hidden_states = False,
)

#unfreezing layer 11 and the classifier. note: the pooler is still frozen
for name, param in model.named_parameters():
    if 'classifier' not in name and '11' not in name:
        param.requires_grad = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-large-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 1024, padding_idx=0)
#       (position_embeddings): Embedding(512, 1024)
#       (token_type_embeddings): Embedding(2, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-23): 24 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=1024, out_features=1024, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=1024, out_features=3, bias=True)
# )

# %%
if torch.cuda.is_available():
    print("CUDA is available. Using GPU:", torch.cuda.get_device_name(0))
else:
    print("CUDA is not available. Using CPU.")

print("Current device model is on:", model.device)
# Out:
# CUDA is available. Using GPU: Tesla V100-SXM2-16GB
# Current device model is on: cuda:0

# %%
optimizer = AdamW(model.parameters(),
                  lr = 5e-5,
                  eps = 1e-8
                 )

epochs = 2
total_steps = len(train_loader) * epochs

scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0,
                                            num_training_steps = total_steps)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:429: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Begin Training Loop
loss_values = []

for epoch_i in range(0, epochs):
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # time taken for each epoch
    t0 = time.time()

    total_loss = 0

    model.train()

    for step, batch in enumerate(train_loader):
        if step % 40 == 0 and not step == 0:
            elapsed = format_time(time.time() - t0)
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_loader), elapsed))

        # Unpack this training batch from our dataloader.
        #
        # As we unpack the batch, we'll also copy each tensor to the GPU using the
        # `to` method.
        #
        # `batch` contains three pytorch tensors:
        #   [0]: input ids
        #   [1]: attention masks
        #   [2]: labels
        b_input_ids = batch['input_ids'].to(device)
        b_input_mask = batch['attention_mask'].to(device)
        b_labels = batch['labels'].to(device)

        # clear previously calculated gradient before backward pass
        model.zero_grad()

        # forward pass
        outputs = model(b_input_ids,
                        token_type_ids=None,
                        attention_mask=b_input_mask,
                        labels=b_labels)

        loss = outputs.loss

        # Accumulate the training loss over all of the batches so that we can
        # calculate the average loss at the end. `loss` is a Tensor containing a
        # single value; the `.item()` function just returns the Python value
        # from the tensor.
        total_loss += loss.item()

        # backwar pass
        loss.backward()

        # Clip the norm of the gradients to 1.0, helps prevents "exploding gradient"
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update parameters and take a step
        optimizer.step()

        # Update the learning rate.
        scheduler.step()

    avg_train_loss = total_loss / len(train_loader)
    loss_values.append(avg_train_loss)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epoch took: {:}".format(format_time(time.time() - t0)))

print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 2 ========
# Training...
#   Batch    40  of  14,625.    Elapsed: 0:00:12.
#   Batch    80  of  14,625.    Elapsed: 0:00:23.
#   Batch   120  of  14,625.    Elapsed: 0:00:34.
#   Batch   160  of  14,625.    Elapsed: 0:00:45.
#   Batch   200  of  14,625.    Elapsed: 0:00:56.
#   Batch   240  of  14,625.    Elapsed: 0:01:07.
#   Batch   280  of  14,625.    Elapsed: 0:01:18.
#   Batch   320  of  14,625.    Elapsed: 0:01:29.
#   Batch   360  of  14,625.    Elapsed: 0:01:40.
#   Batch   400  of  14,625.    Elapsed: 0:01:51.
#   Batch   440  of  14,625.    Elapsed: 0:02:02.
#   Batch   480  of  14,625.    Elapsed: 0:02:13.
#   Batch   520  of  14,625.    Elapsed: 0:02:24.
#   Batch   560  of  14,625.    Elapsed: 0:02:35.
#   Batch   600  of  14,625.    Elapsed: 0:02:46.
#   Batch   640  of  14,625.    Elapsed: 0:02:57.
#   Batch   680  of  14,625.    Elapsed: 0:03:08.
#   Batch   720  of  14,625.    Elapsed: 0:03:19.
#   Batch   760  of  14,625.    Elapsed: 0:03:30.
#   Batch   800  of  14,625.    Elapsed: 0:03:41.
#   Batch   840  of  14,625.    Elapsed: 0:03:52.
#   Batch   880  of  14,625.    Elapsed: 0:04:03.
#   Batch   920  of  14,625.    Elapsed: 0:04:14.
#   Batch   960  of  14,625.    Elapsed: 0:04:25.
#   Batch 1,000  of  14,625.    Elapsed: 0:04:36.
#   Batch 1,040  of  14,625.    Elapsed: 0:04:47.
#   Batch 1,080  of  14,625.    Elapsed: 0:04:58.
#   Batch 1,120  of  14,625.    Elapsed: 0:05:09.
#   Batch 1,160  of  14,625.    Elapsed: 0:05:20.
#   Batch 1,200  of  14,625.    Elapsed: 0:05:31.
#   Batch 1,240  of  14,625.    Elapsed: 0:05:42.
#   Batch 1,280  of  14,625.    Elapsed: 0:05:53.
#   Batch 1,320  of  14,625.    Elapsed: 0:06:03.
#   Batch 1,360  of  14,625.    Elapsed: 0:06:14.
#   Batch 1,400  of  14,625.    Elapsed: 0:06:25.
#   Batch 1,440  of  14,625.    Elapsed: 0:06:36.
#   Batch 1,480  of  14,625.    Elapsed: 0:06:47.
#   Batch 1,520  of  14,625.    Elapsed: 0:06:58.
#   Batch 1,560  of  14,625.    Elapsed: 0:07:09.
#   Batch 1,600  of  14,625.    Elapsed: 0:07:20.
#   Batch 1,640  of  14,625.    Elapsed: 0:07:31.
#   Batch 1,680  of  14,625.    Elapsed: 0:07:42.
#   Batch 1,720  of  14,625.    Elapsed: 0:07:53.
#   Batch 1,760  of  14,625.    Elapsed: 0:08:04.
#   Batch 1,800  of  14,625.    Elapsed: 0:08:15.
#   Batch 1,840  of  14,625.    Elapsed: 0:08:26.
#   Batch 1,880  of  14,625.    Elapsed: 0:08:37.
#   Batch 1,920  of  14,625.    Elapsed: 0:08:48.
#   Batch 1,960  of  14,625.    Elapsed: 0:08:59.
#   Batch 2,000  of  14,625.    Elapsed: 0:09:10.
#   Batch 2,040  of  14,625.    Elapsed: 0:09:21.
#   Batch 2,080  of  14,625.    Elapsed: 0:09:32.
#   Batch 2,120  of  14,625.    Elapsed: 0:09:43.
#   Batch 2,160  of  14,625.    Elapsed: 0:09:54.
#   Batch 2,200  of  14,625.    Elapsed: 0:10:05.
#   Batch 2,240  of  14,625.    Elapsed: 0:10:16.
#   Batch 2,280  of  14,625.    Elapsed: 0:10:27.
#   Batch 2,320  of  14,625.    Elapsed: 0:10:38.
#   Batch 2,360  of  14,625.    Elapsed: 0:10:49.
#   Batch 2,400  of  14,625.    Elapsed: 0:11:00.
#   Batch 2,440  of  14,625.    Elapsed: 0:11:11.
#   Batch 2,480  of  14,625.    Elapsed: 0:11:22.
#   Batch 2,520  of  14,625.    Elapsed: 0:11:33.
#   Batch 2,560  of  14,625.    Elapsed: 0:11:44.
#   Batch 2,600  of  14,625.    Elapsed: 0:11:55.
#   Batch 2,640  of  14,625.    Elapsed: 0:12:06.
#   Batch 2,680  of  14,625.    Elapsed: 0:12:17.
#   Batch 2,720  of  14,625.    Elapsed: 0:12:28.
#   Batch 2,760  of  14,625.    Elapsed: 0:12:39.
#   Batch 2,800  of  14,625.    Elapsed: 0:12:50.
#   Batch 2,840  of  14,625.    Elapsed: 0:13:01.
#   Batch 2,880  of  14,625.    Elapsed: 0:13:12.
#   Batch 2,920  of  14,625.    Elapsed: 0:13:23.
#   Batch 2,960  of  14,625.    Elapsed: 0:13:34.
#   Batch 3,000  of  14,625.    Elapsed: 0:13:45.
#   Batch 3,040  of  14,625.    Elapsed: 0:13:56.
#   Batch 3,080  of  14,625.    Elapsed: 0:14:07.
#   Batch 3,120  of  14,625.    Elapsed: 0:14:18.
#   Batch 3,160  of  14,625.    Elapsed: 0:14:29.
#   Batch 3,200  of  14,625.    Elapsed: 0:14:40.
#   Batch 3,240  of  14,625.    Elapsed: 0:14:51.
#   Batch 3,280  of  14,625.    Elapsed: 0:15:02.
#   Batch 3,320  of  14,625.    Elapsed: 0:15:12.
#   Batch 3,360  of  14,625.    Elapsed: 0:15:23.
#   Batch 3,400  of  14,625.    Elapsed: 0:15:34.
#   Batch 3,440  of  14,625.    Elapsed: 0:15:45.
#   Batch 3,480  of  14,625.    Elapsed: 0:15:56.
#   Batch 3,520  of  14,625.    Elapsed: 0:16:07.
#   Batch 3,560  of  14,625.    Elapsed: 0:16:18.
#   Batch 3,600  of  14,625.    Elapsed: 0:16:29.
#   Batch 3,640  of  14,625.    Elapsed: 0:16:40.
#   Batch 3,680  of  14,625.    Elapsed: 0:16:51.
#   Batch 3,720  of  14,625.    Elapsed: 0:17:02.
#   Batch 3,760  of  14,625.    Elapsed: 0:17:13.
#   Batch 3,800  of  14,625.    Elapsed: 0:17:24.
#   Batch 3,840  of  14,625.    Elapsed: 0:17:35.
#   Batch 3,880  of  14,625.    Elapsed: 0:17:46.
#   Batch 3,920  of  14,625.    Elapsed: 0:17:57.
#   Batch 3,960  of  14,625.    Elapsed: 0:18:08.
#   Batch 4,000  of  14,625.    Elapsed: 0:18:19.
#   Batch 4,040  of  14,625.    Elapsed: 0:18:30.
#   Batch 4,080  of  14,625.    Elapsed: 0:18:41.
#   Batch 4,120  of  14,625.    Elapsed: 0:18:52.
#   Batch 4,160  of  14,625.    Elapsed: 0:19:03.
#   Batch 4,200  of  14,625.    Elapsed: 0:19:14.
#   Batch 4,240  of  14,625.    Elapsed: 0:19:25.
#   Batch 4,280  of  14,625.    Elapsed: 0:19:36.
#   Batch 4,320  of  14,625.    Elapsed: 0:19:47.
#   Batch 4,360  of  14,625.    Elapsed: 0:19:58.
#   Batch 4,400  of  14,625.    Elapsed: 0:20:09.
#   Batch 4,440  of  14,625.    Elapsed: 0:20:20.
#   Batch 4,480  of  14,625.    Elapsed: 0:20:31.
#   Batch 4,520  of  14,625.    Elapsed: 0:20:42.
#   Batch 4,560  of  14,625.    Elapsed: 0:20:53.
#   Batch 4,600  of  14,625.    Elapsed: 0:21:04.
#   Batch 4,640  of  14,625.    Elapsed: 0:21:15.
#   Batch 4,680  of  14,625.    Elapsed: 0:21:26.
#   Batch 4,720  of  14,625.    Elapsed: 0:21:37.
#   Batch 4,760  of  14,625.    Elapsed: 0:21:48.
#   Batch 4,800  of  14,625.    Elapsed: 0:21:59.
#   Batch 4,840  of  14,625.    Elapsed: 0:22:10.
#   Batch 4,880  of  14,625.    Elapsed: 0:22:21.
#   Batch 4,920  of  14,625.    Elapsed: 0:22:32.
#   Batch 4,960  of  14,625.    Elapsed: 0:22:43.
#   Batch 5,000  of  14,625.    Elapsed: 0:22:54.
#   Batch 5,040  of  14,625.    Elapsed: 0:23:05.
#   Batch 5,080  of  14,625.    Elapsed: 0:23:16.
#   Batch 5,120  of  14,625.    Elapsed: 0:23:27.
#   Batch 5,160  of  14,625.    Elapsed: 0:23:38.
#   Batch 5,200  of  14,625.    Elapsed: 0:23:49.
#   Batch 5,240  of  14,625.    Elapsed: 0:24:00.
#   Batch 5,280  of  14,625.    Elapsed: 0:24:11.
#   Batch 5,320  of  14,625.    Elapsed: 0:24:22.
#   Batch 5,360  of  14,625.    Elapsed: 0:24:33.
#   Batch 5,400  of  14,625.    Elapsed: 0:24:44.
#   Batch 5,440  of  14,625.    Elapsed: 0:24:55.
#   Batch 5,480  of  14,625.    Elapsed: 0:25:06.
#   Batch 5,520  of  14,625.    Elapsed: 0:25:16.
#   Batch 5,560  of  14,625.    Elapsed: 0:25:27.
#   Batch 5,600  of  14,625.    Elapsed: 0:25:38.
#   Batch 5,640  of  14,625.    Elapsed: 0:25:49.
#   Batch 5,680  of  14,625.    Elapsed: 0:26:00.
#   Batch 5,720  of  14,625.    Elapsed: 0:26:11.
#   Batch 5,760  of  14,625.    Elapsed: 0:26:22.
#   Batch 5,800  of  14,625.    Elapsed: 0:26:33.
#   Batch 5,840  of  14,625.    Elapsed: 0:26:44.
#   Batch 5,880  of  14,625.    Elapsed: 0:26:55.
#   Batch 5,920  of  14,625.    Elapsed: 0:27:06.
#   Batch 5,960  of  14,625.    Elapsed: 0:27:17.
#   Batch 6,000  of  14,625.    Elapsed: 0:27:28.
#   Batch 6,040  of  14,625.    Elapsed: 0:27:39.
#   Batch 6,080  of  14,625.    Elapsed: 0:27:50.
#   Batch 6,120  of  14,625.    Elapsed: 0:28:01.
#   Batch 6,160  of  14,625.    Elapsed: 0:28:12.
#   Batch 6,200  of  14,625.    Elapsed: 0:28:23.
#   Batch 6,240  of  14,625.    Elapsed: 0:28:34.
#   Batch 6,280  of  14,625.    Elapsed: 0:28:45.
#   Batch 6,320  of  14,625.    Elapsed: 0:28:56.
#   Batch 6,360  of  14,625.    Elapsed: 0:29:07.
#   Batch 6,400  of  14,625.    Elapsed: 0:29:18.
#   Batch 6,440  of  14,625.    Elapsed: 0:29:29.
#   Batch 6,480  of  14,625.    Elapsed: 0:29:40.
#   Batch 6,520  of  14,625.    Elapsed: 0:29:51.
#   Batch 6,560  of  14,625.    Elapsed: 0:30:02.
#   Batch 6,600  of  14,625.    Elapsed: 0:30:13.
#   Batch 6,640  of  14,625.    Elapsed: 0:30:24.
#   Batch 6,680  of  14,625.    Elapsed: 0:30:35.
#   Batch 6,720  of  14,625.    Elapsed: 0:30:46.
#   Batch 6,760  of  14,625.    Elapsed: 0:30:57.
#   Batch 6,800  of  14,625.    Elapsed: 0:31:08.
#   Batch 6,840  of  14,625.    Elapsed: 0:31:19.
#   Batch 6,880  of  14,625.    Elapsed: 0:31:30.
#   Batch 6,920  of  14,625.    Elapsed: 0:31:41.
#   Batch 6,960  of  14,625.    Elapsed: 0:31:52.
#   Batch 7,000  of  14,625.    Elapsed: 0:32:03.
#   Batch 7,040  of  14,625.    Elapsed: 0:32:14.
#   Batch 7,080  of  14,625.    Elapsed: 0:32:25.
#   Batch 7,120  of  14,625.    Elapsed: 0:32:36.
#   Batch 7,160  of  14,625.    Elapsed: 0:32:47.
#   Batch 7,200  of  14,625.    Elapsed: 0:32:58.
#   Batch 7,240  of  14,625.    Elapsed: 0:33:09.
#   Batch 7,280  of  14,625.    Elapsed: 0:33:20.
#   Batch 7,320  of  14,625.    Elapsed: 0:33:31.
#   Batch 7,360  of  14,625.    Elapsed: 0:33:42.
#   Batch 7,400  of  14,625.    Elapsed: 0:33:53.
#   Batch 7,440  of  14,625.    Elapsed: 0:34:04.
#   Batch 7,480  of  14,625.    Elapsed: 0:34:15.
#   Batch 7,520  of  14,625.    Elapsed: 0:34:26.
#   Batch 7,560  of  14,625.    Elapsed: 0:34:37.
#   Batch 7,600  of  14,625.    Elapsed: 0:34:48.
#   Batch 7,640  of  14,625.    Elapsed: 0:34:59.
#   Batch 7,680  of  14,625.    Elapsed: 0:35:10.
#   Batch 7,720  of  14,625.    Elapsed: 0:35:20.
#   Batch 7,760  of  14,625.    Elapsed: 0:35:31.
#   Batch 7,800  of  14,625.    Elapsed: 0:35:42.
#   Batch 7,840  of  14,625.    Elapsed: 0:35:53.
#   Batch 7,880  of  14,625.    Elapsed: 0:36:04.
#   Batch 7,920  of  14,625.    Elapsed: 0:36:15.
#   Batch 7,960  of  14,625.    Elapsed: 0:36:26.
#   Batch 8,000  of  14,625.    Elapsed: 0:36:37.
#   Batch 8,040  of  14,625.    Elapsed: 0:36:48.
#   Batch 8,080  of  14,625.    Elapsed: 0:36:59.
#   Batch 8,120  of  14,625.    Elapsed: 0:37:10.
#   Batch 8,160  of  14,625.    Elapsed: 0:37:21.
#   Batch 8,200  of  14,625.    Elapsed: 0:37:32.
#   Batch 8,240  of  14,625.    Elapsed: 0:37:43.
#   Batch 8,280  of  14,625.    Elapsed: 0:37:54.
#   Batch 8,320  of  14,625.    Elapsed: 0:38:05.
#   Batch 8,360  of  14,625.    Elapsed: 0:38:16.
#   Batch 8,400  of  14,625.    Elapsed: 0:38:27.
#   Batch 8,440  of  14,625.    Elapsed: 0:38:38.
#   Batch 8,480  of  14,625.    Elapsed: 0:38:49.
#   Batch 8,520  of  14,625.    Elapsed: 0:39:00.
#   Batch 8,560  of  14,625.    Elapsed: 0:39:11.
#   Batch 8,600  of  14,625.    Elapsed: 0:39:22.
#   Batch 8,640  of  14,625.    Elapsed: 0:39:33.
#   Batch 8,680  of  14,625.    Elapsed: 0:39:44.
#   Batch 8,720  of  14,625.    Elapsed: 0:39:55.
#   Batch 8,760  of  14,625.    Elapsed: 0:40:06.
#   Batch 8,800  of  14,625.    Elapsed: 0:40:17.
#   Batch 8,840  of  14,625.    Elapsed: 0:40:28.
#   Batch 8,880  of  14,625.    Elapsed: 0:40:39.
#   Batch 8,920  of  14,625.    Elapsed: 0:40:50.
#   Batch 8,960  of  14,625.    Elapsed: 0:41:01.
#   Batch 9,000  of  14,625.    Elapsed: 0:41:12.
#   Batch 9,040  of  14,625.    Elapsed: 0:41:23.
#   Batch 9,080  of  14,625.    Elapsed: 0:41:34.
#   Batch 9,120  of  14,625.    Elapsed: 0:41:45.
#   Batch 9,160  of  14,625.    Elapsed: 0:41:56.
#   Batch 9,200  of  14,625.    Elapsed: 0:42:07.
#   Batch 9,240  of  14,625.    Elapsed: 0:42:18.
#   Batch 9,280  of  14,625.    Elapsed: 0:42:29.
#   Batch 9,320  of  14,625.    Elapsed: 0:42:40.
#   Batch 9,360  of  14,625.    Elapsed: 0:42:51.
#   Batch 9,400  of  14,625.    Elapsed: 0:43:02.
#   Batch 9,440  of  14,625.    Elapsed: 0:43:13.
#   Batch 9,480  of  14,625.    Elapsed: 0:43:24.
#   Batch 9,520  of  14,625.    Elapsed: 0:43:35.
#   Batch 9,560  of  14,625.    Elapsed: 0:43:46.
#   Batch 9,600  of  14,625.    Elapsed: 0:43:56.
#   Batch 9,640  of  14,625.    Elapsed: 0:44:07.
#   Batch 9,680  of  14,625.    Elapsed: 0:44:18.
#   Batch 9,720  of  14,625.    Elapsed: 0:44:29.
#   Batch 9,760  of  14,625.    Elapsed: 0:44:40.
#   Batch 9,800  of  14,625.    Elapsed: 0:44:51.
#   Batch 9,840  of  14,625.    Elapsed: 0:45:02.
#   Batch 9,880  of  14,625.    Elapsed: 0:45:13.
#   Batch 9,920  of  14,625.    Elapsed: 0:45:24.
#   Batch 9,960  of  14,625.    Elapsed: 0:45:35.
#   Batch 10,000  of  14,625.    Elapsed: 0:45:46.
#   Batch 10,040  of  14,625.    Elapsed: 0:45:57.
#   Batch 10,080  of  14,625.    Elapsed: 0:46:08.
#   Batch 10,120  of  14,625.    Elapsed: 0:46:19.
#   Batch 10,160  of  14,625.    Elapsed: 0:46:30.
#   Batch 10,200  of  14,625.    Elapsed: 0:46:41.
#   Batch 10,240  of  14,625.    Elapsed: 0:46:52.
#   Batch 10,280  of  14,625.    Elapsed: 0:47:03.
#   Batch 10,320  of  14,625.    Elapsed: 0:47:14.
#   Batch 10,360  of  14,625.    Elapsed: 0:47:25.
#   Batch 10,400  of  14,625.    Elapsed: 0:47:36.
#   Batch 10,440  of  14,625.    Elapsed: 0:47:47.
#   Batch 10,480  of  14,625.    Elapsed: 0:47:58.
#   Batch 10,520  of  14,625.    Elapsed: 0:48:09.
#   Batch 10,560  of  14,625.    Elapsed: 0:48:20.
#   Batch 10,600  of  14,625.    Elapsed: 0:48:31.
#   Batch 10,640  of  14,625.    Elapsed: 0:48:42.
#   Batch 10,680  of  14,625.    Elapsed: 0:48:53.
#   Batch 10,720  of  14,625.    Elapsed: 0:49:04.
#   Batch 10,760  of  14,625.    Elapsed: 0:49:15.
#   Batch 10,800  of  14,625.    Elapsed: 0:49:26.
#   Batch 10,840  of  14,625.    Elapsed: 0:49:37.
#   Batch 10,880  of  14,625.    Elapsed: 0:49:48.
#   Batch 10,920  of  14,625.    Elapsed: 0:49:59.
#   Batch 10,960  of  14,625.    Elapsed: 0:50:10.
#   Batch 11,000  of  14,625.    Elapsed: 0:50:21.
#   Batch 11,040  of  14,625.    Elapsed: 0:50:32.
#   Batch 11,080  of  14,625.    Elapsed: 0:50:43.
#   Batch 11,120  of  14,625.    Elapsed: 0:50:54.
#   Batch 11,160  of  14,625.    Elapsed: 0:51:05.
#   Batch 11,200  of  14,625.    Elapsed: 0:51:16.
#   Batch 11,240  of  14,625.    Elapsed: 0:51:27.
#   Batch 11,280  of  14,625.    Elapsed: 0:51:38.
#   Batch 11,320  of  14,625.    Elapsed: 0:51:49.
#   Batch 11,360  of  14,625.    Elapsed: 0:52:00.
#   Batch 11,400  of  14,625.    Elapsed: 0:52:11.
#   Batch 11,440  of  14,625.    Elapsed: 0:52:22.
#   Batch 11,480  of  14,625.    Elapsed: 0:52:33.
#   Batch 11,520  of  14,625.    Elapsed: 0:52:44.
#   Batch 11,560  of  14,625.    Elapsed: 0:52:55.
#   Batch 11,600  of  14,625.    Elapsed: 0:53:06.
#   Batch 11,640  of  14,625.    Elapsed: 0:53:17.
#   Batch 11,680  of  14,625.    Elapsed: 0:53:28.
#   Batch 11,720  of  14,625.    Elapsed: 0:53:39.
#   Batch 11,760  of  14,625.    Elapsed: 0:53:50.
#   Batch 11,800  of  14,625.    Elapsed: 0:54:00.
#   Batch 11,840  of  14,625.    Elapsed: 0:54:11.
#   Batch 11,880  of  14,625.    Elapsed: 0:54:22.
#   Batch 11,920  of  14,625.    Elapsed: 0:54:33.
#   Batch 11,960  of  14,625.    Elapsed: 0:54:44.
#   Batch 12,000  of  14,625.    Elapsed: 0:54:55.
#   Batch 12,040  of  14,625.    Elapsed: 0:55:06.
#   Batch 12,080  of  14,625.    Elapsed: 0:55:17.
#   Batch 12,120  of  14,625.    Elapsed: 0:55:28.
#   Batch 12,160  of  14,625.    Elapsed: 0:55:39.
#   Batch 12,200  of  14,625.    Elapsed: 0:55:50.
#   Batch 12,240  of  14,625.    Elapsed: 0:56:01.
#   Batch 12,280  of  14,625.    Elapsed: 0:56:12.
#   Batch 12,320  of  14,625.    Elapsed: 0:56:23.
#   Batch 12,360  of  14,625.    Elapsed: 0:56:34.
#   Batch 12,400  of  14,625.    Elapsed: 0:56:45.
#   Batch 12,440  of  14,625.    Elapsed: 0:56:56.
#   Batch 12,480  of  14,625.    Elapsed: 0:57:07.
#   Batch 12,520  of  14,625.    Elapsed: 0:57:18.
#   Batch 12,560  of  14,625.    Elapsed: 0:57:29.
#   Batch 12,600  of  14,625.    Elapsed: 0:57:40.
#   Batch 12,640  of  14,625.    Elapsed: 0:57:51.
#   Batch 12,680  of  14,625.    Elapsed: 0:58:02.
#   Batch 12,720  of  14,625.    Elapsed: 0:58:13.
#   Batch 12,760  of  14,625.    Elapsed: 0:58:24.
#   Batch 12,800  of  14,625.    Elapsed: 0:58:35.
#   Batch 12,840  of  14,625.    Elapsed: 0:58:46.
#   Batch 12,880  of  14,625.    Elapsed: 0:58:57.
#   Batch 12,920  of  14,625.    Elapsed: 0:59:08.
#   Batch 12,960  of  14,625.    Elapsed: 0:59:19.
#   Batch 13,000  of  14,625.    Elapsed: 0:59:30.
#   Batch 13,040  of  14,625.    Elapsed: 0:59:41.
#   Batch 13,080  of  14,625.    Elapsed: 0:59:52.
#   Batch 13,120  of  14,625.    Elapsed: 1:00:03.
#   Batch 13,160  of  14,625.    Elapsed: 1:00:14.
#   Batch 13,200  of  14,625.    Elapsed: 1:00:25.
#   Batch 13,240  of  14,625.    Elapsed: 1:00:36.
#   Batch 13,280  of  14,625.    Elapsed: 1:00:47.
#   Batch 13,320  of  14,625.    Elapsed: 1:00:57.
#   Batch 13,360  of  14,625.    Elapsed: 1:01:08.
#   Batch 13,400  of  14,625.    Elapsed: 1:01:19.
#   Batch 13,440  of  14,625.    Elapsed: 1:01:30.
#   Batch 13,480  of  14,625.    Elapsed: 1:01:41.
#   Batch 13,520  of  14,625.    Elapsed: 1:01:52.
#   Batch 13,560  of  14,625.    Elapsed: 1:02:03.
#   Batch 13,600  of  14,625.    Elapsed: 1:02:14.
#   Batch 13,640  of  14,625.    Elapsed: 1:02:25.
#   Batch 13,680  of  14,625.    Elapsed: 1:02:36.
#   Batch 13,720  of  14,625.    Elapsed: 1:02:47.
#   Batch 13,760  of  14,625.    Elapsed: 1:02:58.
#   Batch 13,800  of  14,625.    Elapsed: 1:03:09.
#   Batch 13,840  of  14,625.    Elapsed: 1:03:20.
#   Batch 13,880  of  14,625.    Elapsed: 1:03:31.
#   Batch 13,920  of  14,625.    Elapsed: 1:03:42.
#   Batch 13,960  of  14,625.    Elapsed: 1:03:53.
#   Batch 14,000  of  14,625.    Elapsed: 1:04:04.
#   Batch 14,040  of  14,625.    Elapsed: 1:04:15.
#   Batch 14,080  of  14,625.    Elapsed: 1:04:26.
#   Batch 14,120  of  14,625.    Elapsed: 1:04:37.
#   Batch 14,160  of  14,625.    Elapsed: 1:04:48.
#   Batch 14,200  of  14,625.    Elapsed: 1:04:59.
#   Batch 14,240  of  14,625.    Elapsed: 1:05:10.
#   Batch 14,280  of  14,625.    Elapsed: 1:05:21.
#   Batch 14,320  of  14,625.    Elapsed: 1:05:32.
#   Batch 14,360  of  14,625.    Elapsed: 1:05:43.
#   Batch 14,400  of  14,625.    Elapsed: 1:05:54.
#   Batch 14,440  of  14,625.    Elapsed: 1:06:05.
#   Batch 14,480  of  14,625.    Elapsed: 1:06:16.
#   Batch 14,520  of  14,625.    Elapsed: 1:06:27.
#   Batch 14,560  of  14,625.    Elapsed: 1:06:38.
#   Batch 14,600  of  14,625.    Elapsed: 1:06:49.
#
#   Average training loss: 0.16
#   Training epoch took: 1:06:56
#
# ======== Epoch 2 / 2 ========
# Training...
#   Batch    40  of  14,625.    Elapsed: 0:00:11.
#   Batch    80  of  14,625.    Elapsed: 0:00:22.
#   Batch   120  of  14,625.    Elapsed: 0:00:33.
#   Batch   160  of  14,625.    Elapsed: 0:00:44.
#   Batch   200  of  14,625.    Elapsed: 0:00:55.
#   Batch   240  of  14,625.    Elapsed: 0:01:06.
#   Batch   280  of  14,625.    Elapsed: 0:01:17.
#   Batch   320  of  14,625.    Elapsed: 0:01:28.
#   Batch   360  of  14,625.    Elapsed: 0:01:39.
#   Batch   400  of  14,625.    Elapsed: 0:01:50.
#   Batch   440  of  14,625.    Elapsed: 0:02:01.
#   Batch   480  of  14,625.    Elapsed: 0:02:12.
#   Batch   520  of  14,625.    Elapsed: 0:02:23.
#   Batch   560  of  14,625.    Elapsed: 0:02:34.
#   Batch   600  of  14,625.    Elapsed: 0:02:45.
#   Batch   640  of  14,625.    Elapsed: 0:02:56.
#   Batch   680  of  14,625.    Elapsed: 0:03:07.
#   Batch   720  of  14,625.    Elapsed: 0:03:18.
#   Batch   760  of  14,625.    Elapsed: 0:03:29.
#   Batch   800  of  14,625.    Elapsed: 0:03:40.
#   Batch   840  of  14,625.    Elapsed: 0:03:51.
#   Batch   880  of  14,625.    Elapsed: 0:04:02.
#   Batch   920  of  14,625.    Elapsed: 0:04:13.
#   Batch   960  of  14,625.    Elapsed: 0:04:23.
#   Batch 1,000  of  14,625.    Elapsed: 0:04:34.
#   Batch 1,040  of  14,625.    Elapsed: 0:04:45.
#   Batch 1,080  of  14,625.    Elapsed: 0:04:56.
#   Batch 1,120  of  14,625.    Elapsed: 0:05:07.
#   Batch 1,160  of  14,625.    Elapsed: 0:05:18.
#   Batch 1,200  of  14,625.    Elapsed: 0:05:29.
#   Batch 1,240  of  14,625.    Elapsed: 0:05:40.
#   Batch 1,280  of  14,625.    Elapsed: 0:05:51.
#   Batch 1,320  of  14,625.    Elapsed: 0:06:02.
#   Batch 1,360  of  14,625.    Elapsed: 0:06:13.
#   Batch 1,400  of  14,625.    Elapsed: 0:06:24.
#   Batch 1,440  of  14,625.    Elapsed: 0:06:35.
#   Batch 1,480  of  14,625.    Elapsed: 0:06:46.
#   Batch 1,520  of  14,625.    Elapsed: 0:06:57.
#   Batch 1,560  of  14,625.    Elapsed: 0:07:08.
#   Batch 1,600  of  14,625.    Elapsed: 0:07:19.
#   Batch 1,640  of  14,625.    Elapsed: 0:07:30.
#   Batch 1,680  of  14,625.    Elapsed: 0:07:41.
#   Batch 1,720  of  14,625.    Elapsed: 0:07:52.
#   Batch 1,760  of  14,625.    Elapsed: 0:08:03.
#   Batch 1,800  of  14,625.    Elapsed: 0:08:14.
#   Batch 1,840  of  14,625.    Elapsed: 0:08:25.
#   Batch 1,880  of  14,625.    Elapsed: 0:08:36.
#   Batch 1,920  of  14,625.    Elapsed: 0:08:47.
#   Batch 1,960  of  14,625.    Elapsed: 0:08:58.
#   Batch 2,000  of  14,625.    Elapsed: 0:09:09.
#   Batch 2,040  of  14,625.    Elapsed: 0:09:20.
#   Batch 2,080  of  14,625.    Elapsed: 0:09:31.
#   Batch 2,120  of  14,625.    Elapsed: 0:09:42.
#   Batch 2,160  of  14,625.    Elapsed: 0:09:53.
#   Batch 2,200  of  14,625.    Elapsed: 0:10:04.
#   Batch 2,240  of  14,625.    Elapsed: 0:10:15.
#   Batch 2,280  of  14,625.    Elapsed: 0:10:26.
#   Batch 2,320  of  14,625.    Elapsed: 0:10:37.
#   Batch 2,360  of  14,625.    Elapsed: 0:10:48.
#   Batch 2,400  of  14,625.    Elapsed: 0:10:59.
#   Batch 2,440  of  14,625.    Elapsed: 0:11:10.
#   Batch 2,480  of  14,625.    Elapsed: 0:11:21.
#   Batch 2,520  of  14,625.    Elapsed: 0:11:32.
#   Batch 2,560  of  14,625.    Elapsed: 0:11:43.
#   Batch 2,600  of  14,625.    Elapsed: 0:11:54.
#   Batch 2,640  of  14,625.    Elapsed: 0:12:05.
#   Batch 2,680  of  14,625.    Elapsed: 0:12:16.
#   Batch 2,720  of  14,625.    Elapsed: 0:12:27.
#   Batch 2,760  of  14,625.    Elapsed: 0:12:38.
#   Batch 2,800  of  14,625.    Elapsed: 0:12:49.
#   Batch 2,840  of  14,625.    Elapsed: 0:13:00.
#   Batch 2,880  of  14,625.    Elapsed: 0:13:11.
#   Batch 2,920  of  14,625.    Elapsed: 0:13:22.
#   Batch 2,960  of  14,625.    Elapsed: 0:13:33.
#   Batch 3,000  of  14,625.    Elapsed: 0:13:44.
#   Batch 3,040  of  14,625.    Elapsed: 0:13:54.
#   Batch 3,080  of  14,625.    Elapsed: 0:14:05.
#   Batch 3,120  of  14,625.    Elapsed: 0:14:16.
#   Batch 3,160  of  14,625.    Elapsed: 0:14:27.
#   Batch 3,200  of  14,625.    Elapsed: 0:14:38.
#   Batch 3,240  of  14,625.    Elapsed: 0:14:49.
#   Batch 3,280  of  14,625.    Elapsed: 0:15:00.
#   Batch 3,320  of  14,625.    Elapsed: 0:15:11.
#   Batch 3,360  of  14,625.    Elapsed: 0:15:22.
#   Batch 3,400  of  14,625.    Elapsed: 0:15:33.
#   Batch 3,440  of  14,625.    Elapsed: 0:15:44.
#   Batch 3,480  of  14,625.    Elapsed: 0:15:55.
#   Batch 3,520  of  14,625.    Elapsed: 0:16:06.
#   Batch 3,560  of  14,625.    Elapsed: 0:16:17.
#   Batch 3,600  of  14,625.    Elapsed: 0:16:28.
#   Batch 3,640  of  14,625.    Elapsed: 0:16:39.
#   Batch 3,680  of  14,625.    Elapsed: 0:16:50.
#   Batch 3,720  of  14,625.    Elapsed: 0:17:01.
#   Batch 3,760  of  14,625.    Elapsed: 0:17:12.
#   Batch 3,800  of  14,625.    Elapsed: 0:17:23.
#   Batch 3,840  of  14,625.    Elapsed: 0:17:34.
#   Batch 3,880  of  14,625.    Elapsed: 0:17:45.
#   Batch 3,920  of  14,625.    Elapsed: 0:17:56.
#   Batch 3,960  of  14,625.    Elapsed: 0:18:07.
#   Batch 4,000  of  14,625.    Elapsed: 0:18:18.
#   Batch 4,040  of  14,625.    Elapsed: 0:18:29.
#   Batch 4,080  of  14,625.    Elapsed: 0:18:40.
#   Batch 4,120  of  14,625.    Elapsed: 0:18:51.
#   Batch 4,160  of  14,625.    Elapsed: 0:19:02.
#   Batch 4,200  of  14,625.    Elapsed: 0:19:13.
#   Batch 4,240  of  14,625.    Elapsed: 0:19:24.
#   Batch 4,280  of  14,625.    Elapsed: 0:19:35.
#   Batch 4,320  of  14,625.    Elapsed: 0:19:46.
#   Batch 4,360  of  14,625.    Elapsed: 0:19:57.
#   Batch 4,400  of  14,625.    Elapsed: 0:20:08.
#   Batch 4,440  of  14,625.    Elapsed: 0:20:19.
#   Batch 4,480  of  14,625.    Elapsed: 0:20:30.
#   Batch 4,520  of  14,625.    Elapsed: 0:20:41.
#   Batch 4,560  of  14,625.    Elapsed: 0:20:52.
#   Batch 4,600  of  14,625.    Elapsed: 0:21:03.
#   Batch 4,640  of  14,625.    Elapsed: 0:21:14.
#   Batch 4,680  of  14,625.    Elapsed: 0:21:25.
#   Batch 4,720  of  14,625.    Elapsed: 0:21:36.
#   Batch 4,760  of  14,625.    Elapsed: 0:21:47.
#   Batch 4,800  of  14,625.    Elapsed: 0:21:58.
#   Batch 4,840  of  14,625.    Elapsed: 0:22:09.
#   Batch 4,880  of  14,625.    Elapsed: 0:22:20.
#   Batch 4,920  of  14,625.    Elapsed: 0:22:31.
#   Batch 4,960  of  14,625.    Elapsed: 0:22:42.
#   Batch 5,000  of  14,625.    Elapsed: 0:22:53.
#   Batch 5,040  of  14,625.    Elapsed: 0:23:04.
#   Batch 5,080  of  14,625.    Elapsed: 0:23:15.
#   Batch 5,120  of  14,625.    Elapsed: 0:23:26.
#   Batch 5,160  of  14,625.    Elapsed: 0:23:37.
#   Batch 5,200  of  14,625.    Elapsed: 0:23:48.
#   Batch 5,240  of  14,625.    Elapsed: 0:23:59.
#   Batch 5,280  of  14,625.    Elapsed: 0:24:10.
#   Batch 5,320  of  14,625.    Elapsed: 0:24:21.
#   Batch 5,360  of  14,625.    Elapsed: 0:24:32.
#   Batch 5,400  of  14,625.    Elapsed: 0:24:43.
#   Batch 5,440  of  14,625.    Elapsed: 0:24:53.
#   Batch 5,480  of  14,625.    Elapsed: 0:25:04.
#   Batch 5,520  of  14,625.    Elapsed: 0:25:15.
#   Batch 5,560  of  14,625.    Elapsed: 0:25:26.
#   Batch 5,600  of  14,625.    Elapsed: 0:25:37.
#   Batch 5,640  of  14,625.    Elapsed: 0:25:48.
#   Batch 5,680  of  14,625.    Elapsed: 0:25:59.
#   Batch 5,720  of  14,625.    Elapsed: 0:26:10.
#   Batch 5,760  of  14,625.    Elapsed: 0:26:21.
#   Batch 5,800  of  14,625.    Elapsed: 0:26:32.
#   Batch 5,840  of  14,625.    Elapsed: 0:26:43.
#   Batch 5,880  of  14,625.    Elapsed: 0:26:54.
#   Batch 5,920  of  14,625.    Elapsed: 0:27:05.
#   Batch 5,960  of  14,625.    Elapsed: 0:27:16.
#   Batch 6,000  of  14,625.    Elapsed: 0:27:27.
#   Batch 6,040  of  14,625.    Elapsed: 0:27:38.
#   Batch 6,080  of  14,625.    Elapsed: 0:27:49.
#   Batch 6,120  of  14,625.    Elapsed: 0:28:00.
#   Batch 6,160  of  14,625.    Elapsed: 0:28:11.
#   Batch 6,200  of  14,625.    Elapsed: 0:28:22.
#   Batch 6,240  of  14,625.    Elapsed: 0:28:33.
#   Batch 6,280  of  14,625.    Elapsed: 0:28:44.
#   Batch 6,320  of  14,625.    Elapsed: 0:28:55.
#   Batch 6,360  of  14,625.    Elapsed: 0:29:06.
#   Batch 6,400  of  14,625.    Elapsed: 0:29:17.
#   Batch 6,440  of  14,625.    Elapsed: 0:29:28.
#   Batch 6,480  of  14,625.    Elapsed: 0:29:39.
#   Batch 6,520  of  14,625.    Elapsed: 0:29:50.
#   Batch 6,560  of  14,625.    Elapsed: 0:30:01.
#   Batch 6,600  of  14,625.    Elapsed: 0:30:12.
#   Batch 6,640  of  14,625.    Elapsed: 0:30:23.
#   Batch 6,680  of  14,625.    Elapsed: 0:30:34.
#   Batch 6,720  of  14,625.    Elapsed: 0:30:45.
#   Batch 6,760  of  14,625.    Elapsed: 0:30:56.
#   Batch 6,800  of  14,625.    Elapsed: 0:31:07.
#   Batch 6,840  of  14,625.    Elapsed: 0:31:18.
#   Batch 6,880  of  14,625.    Elapsed: 0:31:29.
#   Batch 6,920  of  14,625.    Elapsed: 0:31:40.
#   Batch 6,960  of  14,625.    Elapsed: 0:31:51.
#   Batch 7,000  of  14,625.    Elapsed: 0:32:02.
#   Batch 7,040  of  14,625.    Elapsed: 0:32:13.
#   Batch 7,080  of  14,625.    Elapsed: 0:32:24.
#   Batch 7,120  of  14,625.    Elapsed: 0:32:35.
#   Batch 7,160  of  14,625.    Elapsed: 0:32:46.
#   Batch 7,200  of  14,625.    Elapsed: 0:32:57.
#   Batch 7,240  of  14,625.    Elapsed: 0:33:08.
#   Batch 7,280  of  14,625.    Elapsed: 0:33:19.
#   Batch 7,320  of  14,625.    Elapsed: 0:33:30.
#   Batch 7,360  of  14,625.    Elapsed: 0:33:41.
#   Batch 7,400  of  14,625.    Elapsed: 0:33:52.
#   Batch 7,440  of  14,625.    Elapsed: 0:34:03.
#   Batch 7,480  of  14,625.    Elapsed: 0:34:14.
#   Batch 7,520  of  14,625.    Elapsed: 0:34:24.
#   Batch 7,560  of  14,625.    Elapsed: 0:34:35.
#   Batch 7,600  of  14,625.    Elapsed: 0:34:46.
#   Batch 7,640  of  14,625.    Elapsed: 0:34:57.
#   Batch 7,680  of  14,625.    Elapsed: 0:35:08.
#   Batch 7,720  of  14,625.    Elapsed: 0:35:19.
#   Batch 7,760  of  14,625.    Elapsed: 0:35:30.
#   Batch 7,800  of  14,625.    Elapsed: 0:35:41.
#   Batch 7,840  of  14,625.    Elapsed: 0:35:52.
#   Batch 7,880  of  14,625.    Elapsed: 0:36:03.
#   Batch 7,920  of  14,625.    Elapsed: 0:36:14.
#   Batch 7,960  of  14,625.    Elapsed: 0:36:25.
#   Batch 8,000  of  14,625.    Elapsed: 0:36:36.
#   Batch 8,040  of  14,625.    Elapsed: 0:36:47.
#   Batch 8,080  of  14,625.    Elapsed: 0:36:58.
#   Batch 8,120  of  14,625.    Elapsed: 0:37:09.
#   Batch 8,160  of  14,625.    Elapsed: 0:37:20.
#   Batch 8,200  of  14,625.    Elapsed: 0:37:31.
#   Batch 8,240  of  14,625.    Elapsed: 0:37:42.
#   Batch 8,280  of  14,625.    Elapsed: 0:37:53.
#   Batch 8,320  of  14,625.    Elapsed: 0:38:04.
#   Batch 8,360  of  14,625.    Elapsed: 0:38:15.
#   Batch 8,400  of  14,625.    Elapsed: 0:38:26.
#   Batch 8,440  of  14,625.    Elapsed: 0:38:37.
#   Batch 8,480  of  14,625.    Elapsed: 0:38:48.
#   Batch 8,520  of  14,625.    Elapsed: 0:38:59.
#   Batch 8,560  of  14,625.    Elapsed: 0:39:10.
#   Batch 8,600  of  14,625.    Elapsed: 0:39:21.
#   Batch 8,640  of  14,625.    Elapsed: 0:39:32.
#   Batch 8,680  of  14,625.    Elapsed: 0:39:43.
#   Batch 8,720  of  14,625.    Elapsed: 0:39:54.
#   Batch 8,760  of  14,625.    Elapsed: 0:40:05.
#   Batch 8,800  of  14,625.    Elapsed: 0:40:16.
#   Batch 8,840  of  14,625.    Elapsed: 0:40:27.
#   Batch 8,880  of  14,625.    Elapsed: 0:40:38.
#   Batch 8,920  of  14,625.    Elapsed: 0:40:49.
#   Batch 8,960  of  14,625.    Elapsed: 0:41:00.
#   Batch 9,000  of  14,625.    Elapsed: 0:41:11.
#   Batch 9,040  of  14,625.    Elapsed: 0:41:22.
#   Batch 9,080  of  14,625.    Elapsed: 0:41:33.
#   Batch 9,120  of  14,625.    Elapsed: 0:41:44.
#   Batch 9,160  of  14,625.    Elapsed: 0:41:55.
#   Batch 9,200  of  14,625.    Elapsed: 0:42:06.
#   Batch 9,240  of  14,625.    Elapsed: 0:42:17.
#   Batch 9,280  of  14,625.    Elapsed: 0:42:28.
#   Batch 9,320  of  14,625.    Elapsed: 0:42:39.
#   Batch 9,360  of  14,625.    Elapsed: 0:42:50.
#   Batch 9,400  of  14,625.    Elapsed: 0:43:01.
#   Batch 9,440  of  14,625.    Elapsed: 0:43:11.
#   Batch 9,480  of  14,625.    Elapsed: 0:43:22.
#   Batch 9,520  of  14,625.    Elapsed: 0:43:33.
#   Batch 9,560  of  14,625.    Elapsed: 0:43:44.
#   Batch 9,600  of  14,625.    Elapsed: 0:43:55.
#   Batch 9,640  of  14,625.    Elapsed: 0:44:06.
#   Batch 9,680  of  14,625.    Elapsed: 0:44:17.
#   Batch 9,720  of  14,625.    Elapsed: 0:44:28.
#   Batch 9,760  of  14,625.    Elapsed: 0:44:39.
#   Batch 9,800  of  14,625.    Elapsed: 0:44:50.
#   Batch 9,840  of  14,625.    Elapsed: 0:45:01.
#   Batch 9,880  of  14,625.    Elapsed: 0:45:12.
#   Batch 9,920  of  14,625.    Elapsed: 0:45:23.
#   Batch 9,960  of  14,625.    Elapsed: 0:45:34.
#   Batch 10,000  of  14,625.    Elapsed: 0:45:45.
#   Batch 10,040  of  14,625.    Elapsed: 0:45:56.
#   Batch 10,080  of  14,625.    Elapsed: 0:46:07.
#   Batch 10,120  of  14,625.    Elapsed: 0:46:18.
#   Batch 10,160  of  14,625.    Elapsed: 0:46:29.
#   Batch 10,200  of  14,625.    Elapsed: 0:46:40.
#   Batch 10,240  of  14,625.    Elapsed: 0:46:51.
#   Batch 10,280  of  14,625.    Elapsed: 0:47:02.
#   Batch 10,320  of  14,625.    Elapsed: 0:47:13.
#   Batch 10,360  of  14,625.    Elapsed: 0:47:24.
#   Batch 10,400  of  14,625.    Elapsed: 0:47:35.
#   Batch 10,440  of  14,625.    Elapsed: 0:47:46.
#   Batch 10,480  of  14,625.    Elapsed: 0:47:57.
#   Batch 10,520  of  14,625.    Elapsed: 0:48:08.
#   Batch 10,560  of  14,625.    Elapsed: 0:48:19.
#   Batch 10,600  of  14,625.    Elapsed: 0:48:30.
#   Batch 10,640  of  14,625.    Elapsed: 0:48:41.
#   Batch 10,680  of  14,625.    Elapsed: 0:48:52.
#   Batch 10,720  of  14,625.    Elapsed: 0:49:03.
#   Batch 10,760  of  14,625.    Elapsed: 0:49:14.
#   Batch 10,800  of  14,625.    Elapsed: 0:49:25.
#   Batch 10,840  of  14,625.    Elapsed: 0:49:36.
#   Batch 10,880  of  14,625.    Elapsed: 0:49:47.
#   Batch 10,920  of  14,625.    Elapsed: 0:49:58.
#   Batch 10,960  of  14,625.    Elapsed: 0:50:09.
#   Batch 11,000  of  14,625.    Elapsed: 0:50:20.
#   Batch 11,040  of  14,625.    Elapsed: 0:50:31.
#   Batch 11,080  of  14,625.    Elapsed: 0:50:42.
#   Batch 11,120  of  14,625.    Elapsed: 0:50:53.
#   Batch 11,160  of  14,625.    Elapsed: 0:51:03.
#   Batch 11,200  of  14,625.    Elapsed: 0:51:14.
#   Batch 11,240  of  14,625.    Elapsed: 0:51:25.
#   Batch 11,280  of  14,625.    Elapsed: 0:51:36.
#   Batch 11,320  of  14,625.    Elapsed: 0:51:47.
#   Batch 11,360  of  14,625.    Elapsed: 0:51:58.
#   Batch 11,400  of  14,625.    Elapsed: 0:52:09.
#   Batch 11,440  of  14,625.    Elapsed: 0:52:20.
#   Batch 11,480  of  14,625.    Elapsed: 0:52:31.
#   Batch 11,520  of  14,625.    Elapsed: 0:52:42.
#   Batch 11,560  of  14,625.    Elapsed: 0:52:53.
#   Batch 11,600  of  14,625.    Elapsed: 0:53:04.
#   Batch 11,640  of  14,625.    Elapsed: 0:53:15.
#   Batch 11,680  of  14,625.    Elapsed: 0:53:26.
#   Batch 11,720  of  14,625.    Elapsed: 0:53:37.
#   Batch 11,760  of  14,625.    Elapsed: 0:53:48.
#   Batch 11,800  of  14,625.    Elapsed: 0:53:59.
#   Batch 11,840  of  14,625.    Elapsed: 0:54:10.
#   Batch 11,880  of  14,625.    Elapsed: 0:54:21.
#   Batch 11,920  of  14,625.    Elapsed: 0:54:32.
#   Batch 11,960  of  14,625.    Elapsed: 0:54:43.
#   Batch 12,000  of  14,625.    Elapsed: 0:54:54.
#   Batch 12,040  of  14,625.    Elapsed: 0:55:05.
#   Batch 12,080  of  14,625.    Elapsed: 0:55:16.
#   Batch 12,120  of  14,625.    Elapsed: 0:55:27.
#   Batch 12,160  of  14,625.    Elapsed: 0:55:38.
#   Batch 12,200  of  14,625.    Elapsed: 0:55:49.
#   Batch 12,240  of  14,625.    Elapsed: 0:56:00.
#   Batch 12,280  of  14,625.    Elapsed: 0:56:11.
#   Batch 12,320  of  14,625.    Elapsed: 0:56:22.
#   Batch 12,360  of  14,625.    Elapsed: 0:56:33.
#   Batch 12,400  of  14,625.    Elapsed: 0:56:44.
#   Batch 12,440  of  14,625.    Elapsed: 0:56:55.
#   Batch 12,480  of  14,625.    Elapsed: 0:57:05.
#   Batch 12,520  of  14,625.    Elapsed: 0:57:16.
#   Batch 12,560  of  14,625.    Elapsed: 0:57:27.
#   Batch 12,600  of  14,625.    Elapsed: 0:57:38.
#   Batch 12,640  of  14,625.    Elapsed: 0:57:49.
#   Batch 12,680  of  14,625.    Elapsed: 0:58:00.
#   Batch 12,720  of  14,625.    Elapsed: 0:58:11.
#   Batch 12,760  of  14,625.    Elapsed: 0:58:22.
#   Batch 12,800  of  14,625.    Elapsed: 0:58:33.
#   Batch 12,840  of  14,625.    Elapsed: 0:58:44.
#   Batch 12,880  of  14,625.    Elapsed: 0:58:55.
#   Batch 12,920  of  14,625.    Elapsed: 0:59:06.
#   Batch 12,960  of  14,625.    Elapsed: 0:59:17.
#   Batch 13,000  of  14,625.    Elapsed: 0:59:28.
#   Batch 13,040  of  14,625.    Elapsed: 0:59:39.
#   Batch 13,080  of  14,625.    Elapsed: 0:59:50.
#   Batch 13,120  of  14,625.    Elapsed: 1:00:01.
#   Batch 13,160  of  14,625.    Elapsed: 1:00:12.
#   Batch 13,200  of  14,625.    Elapsed: 1:00:23.
#   Batch 13,240  of  14,625.    Elapsed: 1:00:34.
#   Batch 13,280  of  14,625.    Elapsed: 1:00:45.
#   Batch 13,320  of  14,625.    Elapsed: 1:00:56.
#   Batch 13,360  of  14,625.    Elapsed: 1:01:07.
#   Batch 13,400  of  14,625.    Elapsed: 1:01:18.
#   Batch 13,440  of  14,625.    Elapsed: 1:01:29.
#   Batch 13,480  of  14,625.    Elapsed: 1:01:40.
#   Batch 13,520  of  14,625.    Elapsed: 1:01:51.
#   Batch 13,560  of  14,625.    Elapsed: 1:02:02.
#   Batch 13,600  of  14,625.    Elapsed: 1:02:13.
#   Batch 13,640  of  14,625.    Elapsed: 1:02:24.
#   Batch 13,680  of  14,625.    Elapsed: 1:02:35.
#   Batch 13,720  of  14,625.    Elapsed: 1:02:46.
#   Batch 13,760  of  14,625.    Elapsed: 1:02:57.
#   Batch 13,800  of  14,625.    Elapsed: 1:03:08.
#   Batch 13,840  of  14,625.    Elapsed: 1:03:19.
#   Batch 13,880  of  14,625.    Elapsed: 1:03:29.
#   Batch 13,920  of  14,625.    Elapsed: 1:03:40.
#   Batch 13,960  of  14,625.    Elapsed: 1:03:51.
#   Batch 14,000  of  14,625.    Elapsed: 1:04:02.
#   Batch 14,040  of  14,625.    Elapsed: 1:04:13.
#   Batch 14,080  of  14,625.    Elapsed: 1:04:24.
#   Batch 14,120  of  14,625.    Elapsed: 1:04:35.
#   Batch 14,160  of  14,625.    Elapsed: 1:04:46.
#   Batch 14,200  of  14,625.    Elapsed: 1:04:57.
#   Batch 14,240  of  14,625.    Elapsed: 1:05:08.
#   Batch 14,280  of  14,625.    Elapsed: 1:05:19.
#   Batch 14,320  of  14,625.    Elapsed: 1:05:30.
#   Batch 14,360  of  14,625.    Elapsed: 1:05:41.
#   Batch 14,400  of  14,625.    Elapsed: 1:05:52.
#   Batch 14,440  of  14,625.    Elapsed: 1:06:03.
#   Batch 14,480  of  14,625.    Elapsed: 1:06:14.
#   Batch 14,520  of  14,625.    Elapsed: 1:06:25.
#   Batch 14,560  of  14,625.    Elapsed: 1:06:36.
#   Batch 14,600  of  14,625.    Elapsed: 1:06:47.
#
#   Average training loss: 0.09
#   Training epoch took: 1:06:54
#
# Training complete!

# %%
model.eval()

predictions, true_labels = [], []

# load test cases into GPU in batches
for batch in test_loader:
    batch = {k: v.to(device) for k, v in batch.items()}

    with torch.no_grad():
        outputs = model(**batch)

    logits = outputs.logits
    logits = logits.detach().cpu().numpy()
    label_ids = batch['labels'].to('cpu').numpy()

    predictions.append(logits)
    true_labels.append(label_ids)

predictions = np.argmax(np.concatenate(predictions, axis=0), axis=1)
true_labels = np.concatenate(true_labels, axis=0)

accuracy = accuracy_score(true_labels, predictions)
print("Accuracy:", accuracy)

precision, recall, f1, _ = precision_recall_fscore_support(true_labels, predictions, average='weighted')
print(f"Precision: {precision}\nRecall: {recall}\nF1 Score: {f1}")
# Out:
# Accuracy: 0.9804560260586319
# Precision: 0.9804612724827674
# Recall: 0.9804560260586319
# F1 Score: 0.9804435828480157

# %%
model_save_path = "/content/drive/MyDrive/CS4248/model_large_PHE.pth"
optimizer_save_path = "/content/drive/MyDrive/CS4248/model_large_PHE.pth"

# Save the model, optimizer and encodings state
torch.save(model.state_dict(), model_save_path)
torch.save(optimizer.state_dict(), optimizer_save_path)
